# %% [markdown]
# ### Notebook to train the Teacher and students models

# %%
import os
from google.colab import drive, userdata
drive.mount('/content/drive')
token = userdata.get('githubAccess')
os.environ['WANDB_API_KEY'] = userdata.get('wandbKey')
os.environ["ANTHROPIC_API_KEY"] = userdata.get('anthropic_key')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %pip install -q "transformers>=4.48,<5" "huggingface_hub>=0.34,<1" "datasets<3.0.0" anthropic
# Out:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.13/dist-packages/pip/_internal/cli/base_command.py", line 179, in exc_logging_wrapper
#     status = run_func(*args)
#   File "/usr/local/lib/python3.13/dist-packages/pip/_internal/cli/req_command.py", line 67, in wrapper
#     return func(self, options, args)
#   File "/usr/local/lib/python3.13/dist-packages/pip/_internal/commands/install.py", line 447, in run
#     conflicts = self._determine_conflicts(to_install)
#   File "/usr/local/lib/python3.13/dist-packages/pip/_internal/commands/install.py", line 578, in _determine_conflicts
#     return check_install_conflicts(to_install)
#   File "/usr/local/lib/python3.13/dist-packages/pip/_internal/operations/check.py", line 101, in check_install_conflicts
#     package_set, _ = create_package_set_from_installed()
#                      ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/usr/local/lib/python3.13/dist-packages/pip/_internal/operations/check.py", line 42, in create_package_set_from_installed
#     dependencies = list(dist.iter_dependencies())
#   File "/usr/local/lib/python3.13/dist-packages/pip/_internal/metadata/importlib/_dists.py", line 219, in iter_dependencies
#     for req_string in self.metadata.get_all("Requires-Dist", []):
#                       ^^^^^^^^^^^^^
#   File "/usr/lib/python3.13/functools.py", line 1025, in __get__
#     val = self.func(instance)
#   File "/usr/local/lib/python3.13/dist-packages/pip/_internal/metadata/base.py", line 394, in metadata
#     metadata = self._metadata_impl()
#   File "/usr/local/lib/python3.13/dist-packages/pip/_internal/metadata/importlib/_dists.py", line 209, in _metadata_impl
#     return cast(email.message.Message, self._dist.metadata)
#                                        ^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.13/importlib/metadata/__init__.py", line 471, in metadata
#     return _adapters.Message(email.message_from_string(text))
#            ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.13/importlib/metadata/_adapters.py", line 41, in __new__
#     def __new__(cls, orig: email.message.Message):
#
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/bin/pip3", line 10, in <module>
#     sys.exit(main())
#              ~~~~^^
#   File "/usr/local/lib/python3.13/dist-packages/pip/_internal/cli/main.py", line 80, in main
#     return command.main(cmd_args)
#            ~~~~~~~~~~~~^^^^^^^^^^
#   File "/usr/local/lib/python3.13/dist-packages/pip/_internal/cli/base_command.py", line 100, in main
#     return self._main(args)
#            ~~~~~~~~~~^^^^^^
#   File "/usr/local/lib/python3.13/dist-packages/pip/_internal/cli/base_command.py", line 232, in _main
#     return run(options, args)
#   File "/usr/local/lib/python3.13/dist-packages/pip/_internal/cli/base_command.py", line 215, in exc_logging_wrapper
#     logger.critical("Operation cancelled by user")
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.13/logging/__init__.py", line 1567, in critical
#     self._log(CRITICAL, msg, args, **kwargs)
#     ~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.13/logging/__init__.py", line 1653, in _log
#     fn, lno, func, sinfo = self.findCaller(stack_info, stacklevel)
#                            ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.13/logging/__init__.py", line 1613, in findCaller
#     if not _is_internal_frame(f):
#            ~~~~~~~~~~~~~~~~~~^^^
#   File "/usr/lib/python3.13/logging/__init__.py", line 199, in _is_internal_frame
#     filename = os.path.normcase(frame.f_code.co_filename)
#   File "<frozen posixpath>", line 53, in normcase
# KeyboardInterrupt
# ^C

# %%
import sys
print(sys.version)
# Out:
# 3.13.15 (main, Aug  6 2026, 11:06:22) [GCC 13.3.0]

# %%
# %cd /content/drive/MyDrive/incremental_learning_on_the_edge/src
# Out:
# /content/drive/MyDrive/incremental_learning_on_the_edge/src

# %%
# !git pull
# Out:
# remote: Enumerating objects: 14, done.
# remote: Counting objects: 100% (14/14), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 9 (delta 6), reused 8 (delta 5), pack-reused 0 (from 0)
# Unpacking objects: 100% (9/9), 6.57 KiB | 3.00 KiB/s, done.
# From https://github.com/BrunoSantome/incremental_learning_on_the_edge
#    d7e9b99..9f42212  main       -> origin/main
# Updating d7e9b99..9f42212
# Fast-forward
#  .gitignore                                      |   1 +
#  notebooks/Run_incremental_production_test.ipynb | 370 ++++++++++++++++++++++++
#  src/run_simulation.py                           | 112 ++++++-
#  3 files changed, 477 insertions(+), 6 deletions(-)
#  create mode 100644 notebooks/Run_incremental_production_test.ipynb

# %%
# !python run_simulation.py
# Out:
# Downloading builder script: 100% 32.3k/32.3k [00:00<00:00, 183kB/s]
# Downloading readme: 100% 34.1k/34.1k [00:00<00:00, 259kB/s]
# Downloading data: 100% 39.5M/39.5M [00:01<00:00, 22.6MB/s]
# Generating train split: 11514 examples [00:02, 5625.77 examples/s]
# Generating validation split: 2033 examples [00:00, 2762.41 examples/s]
# Generating test split: 2974 examples [00:00, 3572.85 examples/s]
# Filter: 100% 11514/11514 [00:00<00:00, 206726.69 examples/s]
# Filter: 100% 2974/2974 [00:00<00:00, 185234.26 examples/s]
# Filter: 100% 2033/2033 [00:00<00:00, 160354.67 examples/s]
# Filter: 100% 11514/11514 [00:00<00:00, 218291.20 examples/s]
# Filter: 100% 2974/2974 [00:00<00:00, 184431.80 examples/s]
# Filter: 100% 2033/2033 [00:00<00:00, 171050.13 examples/s]
# Map: 100% 3622/3622 [00:00<00:00, 11940.89 examples/s]
# Map: 100% 914/914 [00:00<00:00, 11782.69 examples/s]
# Map: 100% 657/657 [00:00<00:00, 11709.36 examples/s]
# Casting the dataset: 100% 3622/3622 [00:00<00:00, 812567.88 examples/s]
# Casting the dataset: 100% 914/914 [00:00<00:00, 277334.43 examples/s]
# Casting the dataset: 100% 657/657 [00:00<00:00, 205815.05 examples/s]
# Casting the dataset: 100% 690/690 [00:00<00:00, 70511.40 examples/s]
# Casting the dataset: 100% 150/150 [00:00<00:00, 35891.70 examples/s]
# Casting the dataset: 100% 122/122 [00:00<00:00, 30335.85 examples/s]
# Map: 100% 690/690 [00:00<00:00, 20935.11 examples/s]
# Map: 100% 150/150 [00:00<00:00, 14958.29 examples/s]
# Map: 100% 122/122 [00:00<00:00, 13908.05 examples/s]
# Casting the dataset: 100% 690/690 [00:00<00:00, 251723.91 examples/s]
# Casting the dataset: 100% 150/150 [00:00<00:00, 57688.02 examples/s]
# Casting the dataset: 100% 122/122 [00:00<00:00, 47174.80 examples/s]
# 2026-09-14 20:10:41.161364: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-09-14 20:10:41.236853: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# tokenizer_config.json: 20.8kB [00:00, 65.2MB/s]
# tokenizer.json: 2.13MB [00:00, 95.6MB/s]
# special_tokens_map.json: 100% 694/694 [00:00<00:00, 5.49MB/s]
#
# utterance (exit/quit to stop)> turn on the front lights of the car
# [edge v0] predicted 'news_query' (confidence 0.80)
# [edge] OOD: escalating
# v1: production intent 'car_lights_control'
# Casting the dataset: 100% 93/93 [00:00<00:00, 37252.44 examples/s]
# Casting the dataset: 100% 20/20 [00:00<00:00, 10541.10 examples/s]
# Casting the dataset: 100% 20/20 [00:00<00:00, 11018.79 examples/s]
# Map: 100% 93/93 [00:00<00:00, 14940.64 examples/s]
# Casting the dataset: 100% 93/93 [00:00<00:00, 46271.68 examples/s]
# Map: 100% 20/20 [00:00<00:00, 5675.26 examples/s]
# Casting the dataset: 100% 20/20 [00:00<00:00, 10281.42 examples/s]
# Map: 100% 20/20 [00:00<00:00, 5894.60 examples/s]
# Casting the dataset: 100% 20/20 [00:00<00:00, 10593.01 examples/s]
# Map: 100% 1086/1086 [00:00<00:00, 12528.75 examples/s]
# Map: 100% 934/934 [00:00<00:00, 15796.99 examples/s]
# Map: 100% 677/677 [00:00<00:00, 15216.30 examples/s]
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from WANDB_API_KEY.
# wandb: Currently logged in as: bruno-santome-antolin (bruno-santome-antolin-city-university-of-london) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ Waiting for wandb.init()...
# wandb: ⣾ Waiting for wandb.init()...
# wandb: ⣷ setting up run 5zaz28nq (0.3s)
# wandb: Tracking run with wandb version 0.28.1
# wandb: Run data is saved locally in /content/drive/MyDrive/incremental_learning_on_the_edge/src/wandb/run-20260914_201151-5zaz28nq
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run PRODLIVE_v1_a0.2_s42-v1
# wandb: ⭐️ View project at https://wandb.ai/bruno-santome-antolin-city-university-of-london/kd-multilingual-jhu-clsp-ettin-encoder-68m
# wandb: 🚀 View run at https://wandb.ai/bruno-santome-antolin-city-university-of-london/kd-multilingual-jhu-clsp-ettin-encoder-68m/runs/5zaz28nq
# wandb: Detected [anthropic] in use.
# wandb: Use W&B Weave for improved LLM call tracing. Install Weave with `pip install weave` then add `import weave` to the top of your script.
# wandb: For more information, check out the docs at: https://weave-docs.wandb.ai
# training epoch: 0/20: 100% 34/34 [00:17<00:00,  1.99it/s]
# testing epoch: 0/20: 100% 22/22 [00:01<00:00, 14.57it/s]
# Saving checkpoint
# training epoch: 1/20: 100% 34/34 [00:03<00:00,  9.58it/s]
# testing epoch: 1/20: 100% 22/22 [00:00<00:00, 31.34it/s]
# Saving checkpoint
# training epoch: 2/20: 100% 34/34 [00:03<00:00,  9.25it/s]
# testing epoch: 2/20: 100% 22/22 [00:00<00:00, 31.96it/s]
# training epoch: 3/20: 100% 34/34 [00:03<00:00,  9.80it/s]
# testing epoch: 3/20: 100% 22/22 [00:00<00:00, 29.69it/s]
# training epoch: 4/20: 100% 34/34 [00:03<00:00,  8.87it/s]
# testing epoch: 4/20: 100% 22/22 [00:00<00:00, 28.89it/s]
# Saving checkpoint
# training epoch: 5/20: 100% 34/34 [00:03<00:00,  9.31it/s]
# testing epoch: 5/20: 100% 22/22 [00:00<00:00, 33.14it/s]
# training epoch: 6/20: 100% 34/34 [00:03<00:00,  9.71it/s]
# testing epoch: 6/20: 100% 22/22 [00:00<00:00, 32.58it/s]
# training epoch: 7/20: 100% 34/34 [00:03<00:00,  9.54it/s]
# testing epoch: 7/20: 100% 22/22 [00:00<00:00, 32.46it/s]
# training epoch: 8/20: 100% 34/34 [00:03<00:00,  9.55it/s]
# testing epoch: 8/20: 100% 22/22 [00:00<00:00, 32.13it/s]
# training epoch: 9/20: 100% 34/34 [00:03<00:00,  9.53it/s]
# testing epoch: 9/20: 100% 22/22 [00:00<00:00, 32.29it/s]
# Early stopping at epoch 9
# wandb: ⢿ updating run metadata (0.0s)
# wandb: ⣻ updating run metadata (0.0s)
# wandb: ⣽ updating run metadata (0.0s)
# wandb: ⣾ updating run metadata (0.0s)
# wandb: ⣷ Finishing up...
# wandb: ⣯ Finishing up...
# wandb: ⣟ Finishing up...
# wandb: ⡿ Finishing up...
# wandb: ⢿ Finishing up...
# wandb: ⣻ uploading wandb-summary.json 1.1KB/1.1KB (0.4s)
# wandb: ⣻ uploading config.yaml 2.8KB/2.8KB (0.4s)
# wandb: ⣽ uploading wandb-summary.json 1.1KB/1.1KB (0.4s)
# wandb: ⣽ uploading config.yaml 2.8KB/2.8KB (0.4s)
# wandb: ⣾ uploading wandb-summary.json 1.1KB/1.1KB (0.4s)
# wandb: ⣾ uploading config.yaml 2.8KB/2.8KB (0.4s)
# wandb: ⣷ uploading wandb-summary.json 1.1KB/1.1KB (0.4s)
# wandb: ⣷ uploading config.yaml 2.8KB/2.8KB (0.4s)
# wandb: ⣯ uploading wandb-summary.json 1.1KB/1.1KB (0.4s)
# wandb: ⣯ uploading config.yaml 2.8KB/2.8KB (0.4s)
# wandb: ⣟ uploading config.yaml 2.8KB/2.8KB (0.9s)
# wandb: ⡿ uploading config.yaml 2.8KB/2.8KB (0.9s)
# wandb: ⢿ uploading config.yaml 2.8KB/2.8KB (0.9s)
# wandb:
# wandb: Run history:
# wandb:                      epoch ▁▂▃▃▄▅▆▆▇█
# wandb:              eval_accuracy █▃▄▁▂▄▅▅▃▅
# wandb:        eval_accuracy_en-US █▃▄▁▂▄▅▅▃▅
# wandb:          eval_f1_alarm_set ███▁██████
# wandb:  eval_f1_audio_volume_down ███▁██▁▁█▁
# wandb:  eval_f1_audio_volume_mute ██▄▁██████
# wandb:    eval_f1_audio_volume_up ██▄▁█▄▄▄█▄
# wandb: eval_f1_car_lights_control ▅▆▄▁█▅▆▆▄▆
# wandb:     eval_f1_datetime_query ██▁███████
# wandb:   eval_f1_email_addcontact ▁▁▁▁▁▁▁▁▁▁
# wandb:                        +17 ...
# wandb:
# wandb: Run summary:
# wandb:                      epoch 9
# wandb:              eval_accuracy 0.95569
# wandb:        eval_accuracy_en-US 0.95569
# wandb:          eval_f1_alarm_set 0.96774
# wandb:  eval_f1_audio_volume_down 0.85714
# wandb:  eval_f1_audio_volume_mute 0.9375
# wandb:    eval_f1_audio_volume_up 0.88
# wandb: eval_f1_car_lights_control 0.86957
# wandb:     eval_f1_datetime_query 0.97638
# wandb:   eval_f1_email_addcontact 1
# wandb:                        +17 ...
# wandb:
# wandb: 🚀 View run PRODLIVE_v1_a0.2_s42-v1 at: https://wandb.ai/bruno-santome-antolin-city-university-of-london/kd-multilingual-jhu-clsp-ettin-encoder-68m/runs/5zaz28nq
# wandb: ⭐️ View project at: https://wandb.ai/bruno-santome-antolin-city-university-of-london/kd-multilingual-jhu-clsp-ettin-encoder-68m
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20260914_201151-5zaz28nq/logs
# Filter: 100% 934/934 [00:00<00:00, 113523.82 examples/s]
# Map: 100% 914/914 [00:00<00:00, 12766.60 examples/s]
# evaluating test set: 100% 29/29 [00:00<00:00, 33.22it/s]
# V0: has 15 intents on the test split
# Filter: 100% 934/934 [00:00<00:00, 117374.16 examples/s]
# Map: 100% 934/934 [00:00<00:00, 12601.06 examples/s]
# evaluating test set: 100% 30/30 [00:00<00:00, 33.40it/s]
# V1: has 16 intents on the test split
#
# retention (old intents)
#                          V0        V1
# alarm_set          0.975610  0.963855
# audio_volume_down  1.000000  0.952381
# audio_volume_mute  0.939394  0.939394
# audio_volume_up    0.916667  0.720000
# datetime_query     0.960452  0.960452
# email_addcontact   0.923077  0.923077
# lists_createoradd  0.945946  0.921053
# news_query         0.964427  0.958333
# play_audiobook     0.805195  0.781609
# play_game          0.861538  0.835821
# play_music         0.928962  0.924419
# play_radio         0.936170  0.931507
# transport_query    0.907216  0.929293
# transport_taxi     1.000000  1.000000
# weather_query      0.980769  0.980645
# mean_old           0.936362  0.914789
#
# acquisition (new intents)
#                       V0        V1
# car_lights_control  None  0.727273
# mean_new             NaN  0.727273
# server published v1 (car_lights_control)
# [edge v1] now predicts 'car_lights_control' (confidence 1.00)
#
# utterance (exit/quit to stop)> turn on emergency lights, I had an accident
# [edge v1] predicted 'car_lights_control' (confidence 1.00)
#
# utterance (exit/quit to stop)> Could you lower the left rear window of the car please
# [edge v1] predicted 'car_lights_control' (confidence 1.00)
#
# utterance (exit/quit to stop)> can you show me the direction to the next tacos place
# [edge v1] predicted 'transport_query' (confidence 1.00)
#
# utterance (exit/quit to stop)> open the door of the car
# [edge v1] predicted 'car_lights_control' (confidence 0.64)
# [edge] OOD: escalating
# v2: production intent 'car_door_control'
# Casting the dataset: 100% 94/94 [00:00<00:00, 38978.21 examples/s]
# Casting the dataset: 100% 20/20 [00:00<00:00, 9593.56 examples/s]
# Casting the dataset: 100% 20/20 [00:00<00:00, 9855.04 examples/s]
# Map: 100% 94/94 [00:00<00:00, 14039.76 examples/s]
# Casting the dataset: 100% 94/94 [00:00<00:00, 43608.51 examples/s]
# Map: 100% 20/20 [00:00<00:00, 5285.83 examples/s]
# Casting the dataset: 100% 20/20 [00:00<00:00, 9798.63 examples/s]
# Map: 100% 20/20 [00:00<00:00, 5246.82 examples/s]
# Casting the dataset: 100% 20/20 [00:00<00:00, 9402.16 examples/s]
# Map: 100% 1156/1156 [00:00<00:00, 12522.70 examples/s]
# Map: 100% 954/954 [00:00<00:00, 14895.18 examples/s]
# Map: 100% 697/697 [00:00<00:00, 14314.61 examples/s]
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ Waiting for wandb.init()...
# wandb: ⣾ Waiting for wandb.init()...
# wandb: ⣷ setting up run qsa6j3ao (0.3s)
# wandb: ⣯ setting up run qsa6j3ao (0.3s)
# wandb: ⣟ setting up run qsa6j3ao (0.3s)
# wandb: ⡿ setting up run qsa6j3ao (0.3s)
# wandb: ⢿ setting up run qsa6j3ao (0.3s)
# wandb: ⣻ setting up run qsa6j3ao (0.8s)
# wandb: ⣽ setting up run qsa6j3ao (0.8s)
# wandb: ⣾ setting up run qsa6j3ao (0.8s)
# wandb: ⣷ setting up run qsa6j3ao (0.8s)
# wandb: ⣯ setting up run qsa6j3ao (0.8s)
# wandb: Tracking run with wandb version 0.28.1
# wandb: Run data is saved locally in /content/drive/MyDrive/incremental_learning_on_the_edge/src/wandb/run-20260914_201738-qsa6j3ao
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run PRODLIVE_v2_a0.2_s42-v2
# wandb: ⭐️ View project at https://wandb.ai/bruno-santome-antolin-city-university-of-london/kd-multilingual-jhu-clsp-ettin-encoder-68m
# wandb: 🚀 View run at https://wandb.ai/bruno-santome-antolin-city-university-of-london/kd-multilingual-jhu-clsp-ettin-encoder-68m/runs/qsa6j3ao
# training epoch: 0/20: 100% 37/37 [00:03<00:00,  9.48it/s]
# testing epoch: 0/20: 100% 22/22 [00:00<00:00, 33.19it/s]
# Saving checkpoint
# training epoch: 1/20: 100% 37/37 [00:03<00:00,  9.48it/s]
# testing epoch: 1/20: 100% 22/22 [00:00<00:00, 32.83it/s]
# training epoch: 2/20: 100% 37/37 [00:03<00:00,  9.28it/s]
# testing epoch: 2/20: 100% 22/22 [00:00<00:00, 33.53it/s]
# Saving checkpoint
# training epoch: 3/20: 100% 37/37 [00:04<00:00,  9.17it/s]
# testing epoch: 3/20: 100% 22/22 [00:00<00:00, 32.77it/s]
# Saving checkpoint
# training epoch: 4/20: 100% 37/37 [00:03<00:00,  9.38it/s]
# testing epoch: 4/20: 100% 22/22 [00:00<00:00, 32.09it/s]
# Saving checkpoint
# training epoch: 5/20: 100% 37/37 [00:03<00:00,  9.68it/s]
# testing epoch: 5/20: 100% 22/22 [00:00<00:00, 32.00it/s]
# training epoch: 6/20: 100% 37/37 [00:03<00:00,  9.55it/s]
# testing epoch: 6/20: 100% 22/22 [00:00<00:00, 32.88it/s]
# training epoch: 7/20: 100% 37/37 [00:03<00:00,  9.58it/s]
# testing epoch: 7/20: 100% 22/22 [00:00<00:00, 33.62it/s]
# training epoch: 8/20: 100% 37/37 [00:04<00:00,  8.90it/s]
# testing epoch: 8/20: 100% 22/22 [00:00<00:00, 30.66it/s]
# training epoch: 9/20: 100% 37/37 [00:04<00:00,  9.21it/s]
# testing epoch: 9/20: 100% 22/22 [00:00<00:00, 32.89it/s]
# Early stopping at epoch 9
# wandb: ⢿ updating run metadata (0.0s)
# wandb: ⣻ updating run metadata (0.0s)
# wandb: ⣽ updating run metadata (0.0s)
# wandb: ⣾ updating run metadata (0.0s)
# wandb: ⣷ uploading output.log 1.2KB/1.2KB (0.0s)
# wandb: ⣷ uploading wandb-summary.json 1.1KB/1.1KB (0.0s)
# wandb: ⣷ uploading config.yaml 2.8KB/2.8KB (0.0s)
# wandb: ⣯ uploading output.log 1.2KB/1.2KB (0.0s)
# wandb: ⣯ uploading wandb-summary.json 1.1KB/1.1KB (0.0s)
# wandb: ⣯ uploading config.yaml 2.8KB/2.8KB (0.0s)
# wandb: ⣟ uploading output.log 1.2KB/1.2KB (0.0s)
# wandb: ⣟ uploading wandb-summary.json 1.1KB/1.1KB (0.0s)
# wandb: ⣟ uploading config.yaml 2.8KB/2.8KB (0.0s)
# wandb: ⡿ uploading output.log 1.2KB/1.2KB (0.0s)
# wandb: ⡿ uploading wandb-summary.json 1.1KB/1.1KB (0.0s)
# wandb: ⡿ uploading config.yaml 2.8KB/2.8KB (0.0s)
# wandb: ⢿ uploading output.log 1.2KB/1.2KB (0.0s)
# wandb: ⢿ uploading wandb-summary.json 1.1KB/1.1KB (0.0s)
# wandb: ⢿ uploading config.yaml 2.8KB/2.8KB (0.0s)
# wandb: ⣻ uploading wandb-summary.json 1.1KB/1.1KB (0.5s)
# wandb: ⣻ uploading config.yaml 2.8KB/2.8KB (0.5s)
# wandb: ⣽ uploading wandb-summary.json 1.1KB/1.1KB (0.5s)
# wandb: ⣽ uploading config.yaml 2.8KB/2.8KB (0.5s)
# wandb: ⣾ uploading wandb-summary.json 1.1KB/1.1KB (0.5s)
# wandb: ⣾ uploading config.yaml 2.8KB/2.8KB (0.5s)
# wandb: ⣷ uploading wandb-summary.json 1.1KB/1.1KB (0.5s)
# wandb: ⣷ uploading config.yaml 2.8KB/2.8KB (0.5s)
# wandb: ⣯ uploading wandb-summary.json 1.1KB/1.1KB (0.5s)
# wandb: ⣯ uploading config.yaml 2.8KB/2.8KB (0.5s)
# wandb:
# wandb: Run history:
# wandb:                      epoch ▁▂▃▃▄▅▆▆▇█
# wandb:              eval_accuracy ▁▂▃▇▇▄▆█▇▇
# wandb:        eval_accuracy_en-US ▁▂▃▇▇▄▆█▇▇
# wandb:          eval_f1_alarm_set ▁▁▁▁▁▁▁▁▁▁
# wandb:  eval_f1_audio_volume_down ▁████▁████
# wandb:  eval_f1_audio_volume_mute ██▁███████
# wandb:    eval_f1_audio_volume_up ▁████▁████
# wandb:   eval_f1_car_door_control ▄▁▃▆█▄▅▆▆▆
# wandb: eval_f1_car_lights_control ▁▅▆█▃▅▆▇▅▅
# wandb:     eval_f1_datetime_query ▁▁█▁▁████▁
# wandb:                        +18 ...
# wandb:
# wandb: Run summary:
# wandb:                      epoch 9
# wandb:              eval_accuracy 0.95696
# wandb:        eval_accuracy_en-US 0.95696
# wandb:          eval_f1_alarm_set 0.96774
# wandb:  eval_f1_audio_volume_down 0.93333
# wandb:  eval_f1_audio_volume_mute 0.9375
# wandb:    eval_f1_audio_volume_up 0.91667
# wandb:   eval_f1_car_door_control 0.88889
# wandb: eval_f1_car_lights_control 0.93023
# wandb:     eval_f1_datetime_query 0.97638
# wandb:                        +18 ...
# wandb:
# wandb: 🚀 View run PRODLIVE_v2_a0.2_s42-v2 at: https://wandb.ai/bruno-santome-antolin-city-university-of-london/kd-multilingual-jhu-clsp-ettin-encoder-68m/runs/qsa6j3ao
# wandb: ⭐️ View project at: https://wandb.ai/bruno-santome-antolin-city-university-of-london/kd-multilingual-jhu-clsp-ettin-encoder-68m
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20260914_201738-qsa6j3ao/logs
# Filter: 100% 954/954 [00:00<00:00, 123935.02 examples/s]
# Map: 100% 914/914 [00:00<00:00, 13827.76 examples/s]
# evaluating test set: 100% 29/29 [00:00<00:00, 32.97it/s]
# V0: has 15 intents on the test split
# Filter: 100% 954/954 [00:00<00:00, 118646.88 examples/s]
# Map: 100% 934/934 [00:00<00:00, 12566.09 examples/s]
# evaluating test set: 100% 30/30 [00:00<00:00, 32.42it/s]
# V1: has 16 intents on the test split
# Filter: 100% 954/954 [00:00<00:00, 124158.06 examples/s]
# Map: 100% 954/954 [00:00<00:00, 12555.35 examples/s]
# evaluating test set: 100% 30/30 [00:00<00:00, 32.00it/s]
# V2: has 17 intents on the test split
#
# retention (old intents)
#                          V0        V1        V2
# alarm_set          0.975610  0.963855  0.975610
# audio_volume_down  1.000000  0.952381  1.000000
# audio_volume_mute  0.939394  0.939394  0.953846
# audio_volume_up    0.916667  0.720000  0.818182
# datetime_query     0.960452  0.960452  0.960452
# email_addcontact   0.923077  0.923077  0.923077
# lists_createoradd  0.945946  0.921053  0.933333
# news_query         0.964427  0.958333  0.967742
# play_audiobook     0.805195  0.781609  0.805195
# play_game          0.861538  0.835821  0.882353
# play_music         0.928962  0.924419  0.920000
# play_radio         0.936170  0.931507  0.928571
# transport_query    0.907216  0.929293  0.916667
# transport_taxi     1.000000  1.000000  0.977778
# weather_query      0.980769  0.980645  0.980519
# mean_old           0.936362  0.914789  0.929555
#
# acquisition (new intents)
#                       V0        V1        V2
# car_lights_control  None  0.727273  0.760000
# car_door_control    None       NaN  0.666667
# mean_new             NaN  0.727273  0.713333
# server published v2 (car_door_control)
# [edge v2] now predicts 'car_door_control' (confidence 1.00)
#
# utterance (exit/quit to stop)> Can you check if there is any speed cameras
# [edge v2] predicted 'car_lights_control' (confidence 0.87)
# [edge] OOD: escalating
# v3: production intent 'speed_camera_query'
# Casting the dataset: 100% 94/94 [00:00<00:00, 44680.94 examples/s]
# Casting the dataset: 100% 20/20 [00:00<00:00, 9589.17 examples/s]
# Casting the dataset: 100% 20/20 [00:00<00:00, 9928.52 examples/s]
# Map: 100% 94/94 [00:00<00:00, 15055.16 examples/s]
# Casting the dataset: 100% 94/94 [00:00<00:00, 46908.34 examples/s]
# Map: 100% 20/20 [00:00<00:00, 5371.12 examples/s]
# Casting the dataset: 100% 20/20 [00:00<00:00, 9978.12 examples/s]
# Map: 100% 20/20 [00:00<00:00, 6193.60 examples/s]
# Casting the dataset: 100% 20/20 [00:00<00:00, 10232.51 examples/s]
# Map: 100% 1226/1226 [00:00<00:00, 13070.88 examples/s]
# Map: 100% 974/974 [00:00<00:00, 15602.03 examples/s]
# Map: 100% 717/717 [00:00<00:00, 14747.67 examples/s]
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ Waiting for wandb.init()...
# wandb: ⣾ Waiting for wandb.init()...
# wandb: ⣷ setting up run uqw4isp5 (0.4s)
# wandb: ⣯ setting up run uqw4isp5 (0.4s)
# wandb: Tracking run with wandb version 0.28.1
# wandb: Run data is saved locally in /content/drive/MyDrive/incremental_learning_on_the_edge/src/wandb/run-20260914_201930-uqw4isp5
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run PRODLIVE_v3_a0.2_s42-v3
# wandb: ⭐️ View project at https://wandb.ai/bruno-santome-antolin-city-university-of-london/kd-multilingual-jhu-clsp-ettin-encoder-68m
# wandb: 🚀 View run at https://wandb.ai/bruno-santome-antolin-city-university-of-london/kd-multilingual-jhu-clsp-ettin-encoder-68m/runs/uqw4isp5
# training epoch: 0/20: 100% 39/39 [00:04<00:00,  9.51it/s]
# testing epoch: 0/20: 100% 23/23 [00:00<00:00, 32.17it/s]
# Saving checkpoint
# training epoch: 1/20: 100% 39/39 [00:04<00:00,  9.62it/s]
# testing epoch: 1/20: 100% 23/23 [00:00<00:00, 33.38it/s]
# training epoch: 2/20: 100% 39/39 [00:04<00:00,  9.49it/s]
# testing epoch: 2/20: 100% 23/23 [00:00<00:00, 27.96it/s]
# Saving checkpoint
# training epoch: 3/20: 100% 39/39 [00:04<00:00,  9.02it/s]
# testing epoch: 3/20: 100% 23/23 [00:00<00:00, 33.12it/s]
# training epoch: 4/20: 100% 39/39 [00:04<00:00,  9.48it/s]
# testing epoch: 4/20: 100% 23/23 [00:00<00:00, 32.30it/s]
# training epoch: 5/20: 100% 39/39 [00:04<00:00,  9.35it/s]
# testing epoch: 5/20: 100% 23/23 [00:00<00:00, 30.34it/s]
# training epoch: 6/20: 100% 39/39 [00:04<00:00,  9.58it/s]
# testing epoch: 6/20: 100% 23/23 [00:00<00:00, 32.31it/s]
# training epoch: 7/20: 100% 39/39 [00:04<00:00,  9.41it/s]
# testing epoch: 7/20: 100% 23/23 [00:00<00:00, 32.48it/s]
# Early stopping at epoch 7
# wandb: ⢿ updating run metadata (0.0s)
# wandb: ⣻ updating run metadata (0.0s)
# wandb: ⣽ updating run metadata (0.0s)
# wandb: ⣾ updating run metadata (0.0s)
# wandb: ⣷ Finishing up...
# wandb: ⣯ Finishing up...
# wandb: ⣟ Finishing up...
# wandb: ⡿ Finishing up...
# wandb: ⢿ Finishing up...
# wandb: ⣻ uploading wandb-summary.json 1.2KB/1.2KB (0.5s)
# wandb: ⣻ uploading config.yaml 2.8KB/2.8KB (0.5s)
# wandb: ⣽ uploading wandb-summary.json 1.2KB/1.2KB (0.5s)
# wandb: ⣽ uploading config.yaml 2.8KB/2.8KB (0.5s)
# wandb: ⣾ uploading wandb-summary.json 1.2KB/1.2KB (0.5s)
# wandb: ⣾ uploading config.yaml 2.8KB/2.8KB (0.5s)
# wandb: ⣷ uploading wandb-summary.json 1.2KB/1.2KB (0.5s)
# wandb: ⣷ uploading config.yaml 2.8KB/2.8KB (0.5s)
# wandb: ⣯ uploading wandb-summary.json 1.2KB/1.2KB (0.5s)
# wandb: ⣯ uploading config.yaml 2.8KB/2.8KB (0.5s)
# wandb:
# wandb: Run history:
# wandb:                      epoch ▁▂▃▄▅▆▇█
# wandb:              eval_accuracy ▇▁█▆▇▆▆▇
# wandb:        eval_accuracy_en-US ▇▁█▆▇▆▆▇
# wandb:          eval_f1_alarm_set ▁▁▁▁▁▁▁▁
# wandb:  eval_f1_audio_volume_down ████▁▁▁▁
# wandb:  eval_f1_audio_volume_mute ▁███████
# wandb:    eval_f1_audio_volume_up █▅▅▃▁▁▁▁
# wandb:   eval_f1_car_door_control ▁█▆▆█▃█▃
# wandb: eval_f1_car_lights_control ▁█▃████▆
# wandb:     eval_f1_datetime_query █▁█▁▁█▁█
# wandb:                        +19 ...
# wandb:
# wandb: Run summary:
# wandb:                      epoch 7
# wandb:              eval_accuracy 0.94979
# wandb:        eval_accuracy_en-US 0.94979
# wandb:          eval_f1_alarm_set 0.96774
# wandb:  eval_f1_audio_volume_down 0.85714
# wandb:  eval_f1_audio_volume_mute 0.9375
# wandb:    eval_f1_audio_volume_up 0.84615
# wandb:   eval_f1_car_door_control 0.90909
# wandb: eval_f1_car_lights_control 0.95238
# wandb:     eval_f1_datetime_query 0.98413
# wandb:                        +19 ...
# wandb:
# wandb: 🚀 View run PRODLIVE_v3_a0.2_s42-v3 at: https://wandb.ai/bruno-santome-antolin-city-university-of-london/kd-multilingual-jhu-clsp-ettin-encoder-68m/runs/uqw4isp5
# wandb: ⭐️ View project at: https://wandb.ai/bruno-santome-antolin-city-university-of-london/kd-multilingual-jhu-clsp-ettin-encoder-68m
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20260914_201930-uqw4isp5/logs
# Filter: 100% 974/974 [00:00<00:00, 120919.11 examples/s]
# Map: 100% 914/914 [00:00<00:00, 13484.71 examples/s]
# evaluating test set: 100% 29/29 [00:00<00:00, 33.34it/s]
# V0: has 15 intents on the test split
# Filter: 100% 974/974 [00:00<00:00, 123339.54 examples/s]
# Map: 100% 934/934 [00:00<00:00, 13971.94 examples/s]
# evaluating test set: 100% 30/30 [00:00<00:00, 33.54it/s]
# V1: has 16 intents on the test split
# Filter: 100% 974/974 [00:00<00:00, 124542.77 examples/s]
# Map: 100% 954/954 [00:00<00:00, 13948.89 examples/s]
# evaluating test set: 100% 30/30 [00:00<00:00, 32.74it/s]
# V2: has 17 intents on the test split
# Filter: 100% 974/974 [00:00<00:00, 109030.19 examples/s]
# Map: 100% 974/974 [00:00<00:00, 12646.63 examples/s]
# evaluating test set: 100% 31/31 [00:00<00:00, 32.92it/s]
# V3: has 18 intents on the test split
#
# retention (old intents)
#                          V0        V1        V2        V3
# alarm_set          0.975610  0.963855  0.975610  0.987654
# audio_volume_down  1.000000  0.952381  1.000000  1.000000
# audio_volume_mute  0.939394  0.939394  0.953846  0.939394
# audio_volume_up    0.916667  0.720000  0.818182  0.818182
# datetime_query     0.960452  0.960452  0.960452  0.966667
# email_addcontact   0.923077  0.923077  0.923077  0.923077
# lists_createoradd  0.945946  0.921053  0.933333  0.933333
# news_query         0.964427  0.958333  0.967742  0.971429
# play_audiobook     0.805195  0.781609  0.805195  0.784810
# play_game          0.861538  0.835821  0.882353  0.848485
# play_music         0.928962  0.924419  0.920000  0.919540
# play_radio         0.936170  0.931507  0.928571  0.930556
# transport_query    0.907216  0.929293  0.916667  0.916667
# transport_taxi     1.000000  1.000000  0.977778  0.977778
# weather_query      0.980769  0.980645  0.980519  0.963455
# mean_old           0.936362  0.914789  0.929555  0.925402
#
# acquisition (new intents)
#                       V0        V1        V2        V3
# car_lights_control  None  0.727273  0.760000  0.760000
# car_door_control    None       NaN  0.666667  0.730769
# speed_camera_query  None       NaN       NaN  0.800000
# mean_new             NaN  0.727273  0.713333  0.763590
# server published v3 (speed_camera_query)
# [edge v3] now predicts 'speed_camera_query' (confidence 1.00)
#
# utterance (exit/quit to stop)> turn on the emergency brakes
# [edge v3] predicted 'car_lights_control' (confidence 0.91)
# [edge] OOD: escalating
# v4: production intent 'car_brake_control'
# Casting the dataset: 100% 95/95 [00:00<00:00, 41184.38 examples/s]
# Casting the dataset: 100% 20/20 [00:00<00:00, 9522.77 examples/s]
# Casting the dataset: 100% 20/20 [00:00<00:00, 9616.65 examples/s]
# Map: 100% 95/95 [00:00<00:00, 14280.66 examples/s]
# Casting the dataset: 100% 95/95 [00:00<00:00, 46977.00 examples/s]
# Map: 100% 20/20 [00:00<00:00, 5023.42 examples/s]
# Casting the dataset: 100% 20/20 [00:00<00:00, 9531.43 examples/s]
# Map: 100% 20/20 [00:00<00:00, 4978.11 examples/s]
# Casting the dataset: 100% 20/20 [00:00<00:00, 9255.88 examples/s]
# Map: 100% 1296/1296 [00:00<00:00, 11844.93 examples/s]
# Map: 100% 994/994 [00:00<00:00, 14674.17 examples/s]
# Map: 100% 737/737 [00:00<00:00, 14211.44 examples/s]
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ Waiting for wandb.init()...
# wandb: ⣾ Waiting for wandb.init()...
# wandb: ⣷ setting up run 2pf8g7oy (0.4s)
# wandb: Tracking run with wandb version 0.28.1
# wandb: Run data is saved locally in /content/drive/MyDrive/incremental_learning_on_the_edge/src/wandb/run-20260914_202154-2pf8g7oy
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run PRODLIVE_v4_a0.2_s42-v4
# wandb: ⭐️ View project at https://wandb.ai/bruno-santome-antolin-city-university-of-london/kd-multilingual-jhu-clsp-ettin-encoder-68m
# wandb: 🚀 View run at https://wandb.ai/bruno-santome-antolin-city-university-of-london/kd-multilingual-jhu-clsp-ettin-encoder-68m/runs/2pf8g7oy
# training epoch: 0/20: 100% 41/41 [00:04<00:00,  9.40it/s]
# testing epoch: 0/20: 100% 24/24 [00:02<00:00, 11.67it/s]
# Saving checkpoint
# training epoch: 1/20: 100% 41/41 [00:04<00:00,  9.33it/s]
# testing epoch: 1/20: 100% 24/24 [00:00<00:00, 32.12it/s]
# Saving checkpoint
# training epoch: 2/20: 100% 41/41 [00:04<00:00,  8.77it/s]
# testing epoch: 2/20: 100% 24/24 [00:00<00:00, 31.60it/s]
# training epoch: 3/20: 100% 41/41 [00:04<00:00,  9.36it/s]
# testing epoch: 3/20: 100% 24/24 [00:00<00:00, 32.06it/s]
# Saving checkpoint
# training epoch: 4/20: 100% 41/41 [00:04<00:00,  8.82it/s]
# testing epoch: 4/20: 100% 24/24 [00:00<00:00, 31.82it/s]
# training epoch: 5/20: 100% 41/41 [00:04<00:00,  9.51it/s]
# testing epoch: 5/20: 100% 24/24 [00:00<00:00, 31.89it/s]
# training epoch: 6/20: 100% 41/41 [00:04<00:00,  9.26it/s]
# testing epoch: 6/20: 100% 24/24 [00:00<00:00, 30.35it/s]
# training epoch: 7/20: 100% 41/41 [00:04<00:00,  9.06it/s]
# testing epoch: 7/20: 100% 24/24 [00:00<00:00, 33.73it/s]
# training epoch: 8/20: 100% 41/41 [00:04<00:00,  9.52it/s]
# testing epoch: 8/20: 100% 24/24 [00:00<00:00, 32.01it/s]
# Saving checkpoint
# training epoch: 9/20: 100% 41/41 [00:04<00:00,  9.47it/s]
# testing epoch: 9/20: 100% 24/24 [00:00<00:00, 33.84it/s]
# Saving checkpoint
# training epoch: 10/20: 100% 41/41 [00:04<00:00,  9.64it/s]
# testing epoch: 10/20: 100% 24/24 [00:00<00:00, 32.45it/s]
# Saving checkpoint
# training epoch: 11/20: 100% 41/41 [00:04<00:00,  9.42it/s]
# testing epoch: 11/20: 100% 24/24 [00:00<00:00, 33.05it/s]
# Saving checkpoint
# training epoch: 12/20: 100% 41/41 [00:04<00:00,  9.53it/s]
# testing epoch: 12/20: 100% 24/24 [00:00<00:00, 32.10it/s]
# training epoch: 13/20: 100% 41/41 [00:04<00:00,  9.28it/s]
# testing epoch: 13/20: 100% 24/24 [00:00<00:00, 33.31it/s]
# training epoch: 14/20: 100% 41/41 [00:04<00:00,  9.75it/s]
# testing epoch: 14/20: 100% 24/24 [00:00<00:00, 32.87it/s]
# training epoch: 15/20: 100% 41/41 [00:04<00:00,  9.38it/s]
# testing epoch: 15/20: 100% 24/24 [00:00<00:00, 31.56it/s]
# training epoch: 16/20: 100% 41/41 [00:04<00:00,  9.51it/s]
# testing epoch: 16/20: 100% 24/24 [00:00<00:00, 32.16it/s]
# Saving checkpoint
# training epoch: 17/20: 100% 41/41 [00:04<00:00,  9.32it/s]
# testing epoch: 17/20: 100% 24/24 [00:00<00:00, 32.37it/s]
# training epoch: 18/20: 100% 41/41 [00:04<00:00,  9.47it/s]
# testing epoch: 18/20: 100% 24/24 [00:00<00:00, 32.67it/s]
# training epoch: 19/20: 100% 41/41 [00:04<00:00,  9.29it/s]
# testing epoch: 19/20: 100% 24/24 [00:00<00:00, 30.12it/s]
# wandb: ⢿ updating run metadata (1.1s)
# wandb: ⣻ updating run metadata (1.1s)
# wandb: ⣽ updating run metadata (1.1s)
# wandb: ⣾ updating run metadata (1.1s)
# wandb: ⣷ uploading output.log 2.4KB/2.4KB (0.0s)
# wandb: ⣷ uploading wandb-summary.json 1.2KB/1.2KB (0.0s)
# wandb: ⣷ uploading config.yaml (0.0s)
# wandb: ⣯ uploading output.log 2.4KB/2.4KB (0.0s)
# wandb: ⣯ uploading wandb-summary.json 1.2KB/1.2KB (0.0s)
# wandb: ⣯ uploading config.yaml (0.0s)
# wandb: ⣟ uploading output.log 2.4KB/2.4KB (0.0s)
# wandb: ⣟ uploading wandb-summary.json 1.2KB/1.2KB (0.0s)
# wandb: ⣟ uploading config.yaml (0.0s)
# wandb: ⡿ uploading output.log 2.4KB/2.4KB (0.0s)
# wandb: ⡿ uploading wandb-summary.json 1.2KB/1.2KB (0.0s)
# wandb: ⡿ uploading config.yaml (0.0s)
# wandb: ⢿ uploading output.log 2.4KB/2.4KB (0.0s)
# wandb: ⢿ uploading wandb-summary.json 1.2KB/1.2KB (0.0s)
# wandb: ⢿ uploading config.yaml (0.0s)
# wandb: ⣻ uploading wandb-summary.json 1.2KB/1.2KB (0.5s)
# wandb: ⣻ uploading config.yaml 2.9KB/2.9KB (0.5s)
# wandb: ⣽ uploading wandb-summary.json 1.2KB/1.2KB (0.5s)
# wandb: ⣽ uploading config.yaml 2.9KB/2.9KB (0.5s)
# wandb: ⣾ uploading wandb-summary.json 1.2KB/1.2KB (0.5s)
# wandb: ⣾ uploading config.yaml 2.9KB/2.9KB (0.5s)
# wandb: ⣷ uploading wandb-summary.json 1.2KB/1.2KB (0.5s)
# wandb: ⣷ uploading config.yaml 2.9KB/2.9KB (0.5s)
# wandb: ⣯ uploading wandb-summary.json 1.2KB/1.2KB (0.5s)
# wandb: ⣯ uploading config.yaml 2.9KB/2.9KB (0.5s)
# wandb: ⣟ uploading history steps 754-839, summary, console lines 42-47 (0.2s)
# wandb: ⡿ uploading history steps 754-839, summary, console lines 42-47 (0.2s)
# wandb: ⢿ uploading history steps 754-839, summary, console lines 42-47 (0.2s)
# wandb: ⣻ uploading history steps 754-839, summary, console lines 42-47 (0.2s)
# wandb:
# wandb: Run history:
# wandb:                      epoch ▁▁▂▂▂▃▃▄▄▄▅▅▅▆▆▇▇▇██
# wandb:              eval_accuracy ▃▃▄▄▁▂▄▃▄█▄▆▆▆▆▆▇▇▇▇
# wandb:        eval_accuracy_en-US ▃▃▄▄▁▂▄▃▄█▄▆▆▆▆▆▇▇▇▇
# wandb:          eval_f1_alarm_set ▁▁██████████████████
# wandb:  eval_f1_audio_volume_down ▁█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:  eval_f1_audio_volume_mute █▁█▁████████████████
# wandb:    eval_f1_audio_volume_up █▄▄▁▄▄▄▄▄▄▄▄▄▄▄▄▄▁▁▁
# wandb:  eval_f1_car_brake_control ▂▅▁▆▄▃▅▆▆▆▇▇▇▇▇▇████
# wandb:   eval_f1_car_door_control ▃█▃▃██▆▃▃█▁▃▃▃▃▃▃▆▆▆
# wandb: eval_f1_car_lights_control ▁▄█▁█▄▄▁▄███████████
# wandb:                        +20 ...
# wandb:
# wandb: Run summary:
# wandb:                      epoch 19
# wandb:              eval_accuracy 0.9498
# wandb:        eval_accuracy_en-US 0.9498
# wandb:          eval_f1_alarm_set 0.96774
# wandb:  eval_f1_audio_volume_down 0.85714
# wandb:  eval_f1_audio_volume_mute 0.9375
# wandb:    eval_f1_audio_volume_up 0.84615
# wandb:  eval_f1_car_brake_control 0.97561
# wandb:   eval_f1_car_door_control 0.93023
# wandb: eval_f1_car_lights_control 0.97561
# wandb:                        +20 ...
# wandb:
# wandb: 🚀 View run PRODLIVE_v4_a0.2_s42-v4 at: https://wandb.ai/bruno-santome-antolin-city-university-of-london/kd-multilingual-jhu-clsp-ettin-encoder-68m/runs/2pf8g7oy
# wandb: ⭐️ View project at: https://wandb.ai/bruno-santome-antolin-city-university-of-london/kd-multilingual-jhu-clsp-ettin-encoder-68m
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20260914_202154-2pf8g7oy/logs
# Filter: 100% 994/994 [00:00<00:00, 115427.84 examples/s]
# Map: 100% 914/914 [00:00<00:00, 10024.22 examples/s]
# evaluating test set: 100% 29/29 [00:00<00:00, 30.63it/s]
# V0: has 15 intents on the test split
# Filter: 100% 994/994 [00:00<00:00, 120568.50 examples/s]
# Map: 100% 934/934 [00:00<00:00, 13306.84 examples/s]
# evaluating test set: 100% 30/30 [00:00<00:00, 32.83it/s]
# V1: has 16 intents on the test split
# Filter: 100% 994/994 [00:00<00:00, 125278.35 examples/s]
# Map: 100% 954/954 [00:00<00:00, 13446.85 examples/s]
# evaluating test set: 100% 30/30 [00:00<00:00, 33.86it/s]
# V2: has 17 intents on the test split
# Filter: 100% 994/994 [00:00<00:00, 123709.63 examples/s]
# Map: 100% 974/974 [00:00<00:00, 13379.66 examples/s]
# evaluating test set: 100% 31/31 [00:00<00:00, 32.65it/s]
# V3: has 18 intents on the test split
# Filter: 100% 994/994 [00:00<00:00, 117202.80 examples/s]
# Map: 100% 994/994 [00:00<00:00, 12648.66 examples/s]
# evaluating test set: 100% 32/32 [00:00<00:00, 32.36it/s]
# V4: has 19 intents on the test split
#
# retention (old intents)
#                          V0        V1        V2        V3        V4
# alarm_set          0.975610  0.963855  0.975610  0.987654  0.975610
# audio_volume_down  1.000000  0.952381  1.000000  1.000000  1.000000
# audio_volume_mute  0.939394  0.939394  0.953846  0.939394  0.953846
# audio_volume_up    0.916667  0.720000  0.818182  0.818182  0.833333
# datetime_query     0.960452  0.960452  0.960452  0.966667  0.960452
# email_addcontact   0.923077  0.923077  0.923077  0.923077  0.923077
# lists_createoradd  0.945946  0.921053  0.933333  0.933333  0.935065
# news_query         0.964427  0.958333  0.967742  0.971429  0.967213
# play_audiobook     0.805195  0.781609  0.805195  0.784810  0.784810
# play_game          0.861538  0.835821  0.882353  0.848485  0.882353
# play_music         0.928962  0.924419  0.920000  0.919540  0.907514
# play_radio         0.936170  0.931507  0.928571  0.930556  0.915493
# transport_query    0.907216  0.929293  0.916667  0.916667  0.905263
# transport_taxi     1.000000  1.000000  0.977778  0.977778  1.000000
# weather_query      0.980769  0.980645  0.980519  0.963455  0.963696
# mean_old           0.936362  0.914789  0.929555  0.925402  0.927182
#
# acquisition (new intents)
#                       V0        V1        V2        V3        V4
# car_lights_control  None  0.727273  0.760000  0.760000  0.808511
# car_door_control    None       NaN  0.666667  0.730769  0.703704
# speed_camera_query  None       NaN       NaN  0.800000  0.784314
# car_brake_control   None       NaN       NaN       NaN  0.950000
# mean_new             NaN  0.727273  0.713333  0.763590  0.811632
# server published v4 (car_brake_control)
# [edge v4] now predicts 'car_brake_control' (confidence 1.00)
#
# utterance (exit/quit to stop)> tell me a funny joke
# [edge v4] predicted 'news_query' (confidence 0.53)
# [edge] OOD: escalating
# v5: production intent 'tell_joke'
# Casting the dataset: 100% 95/95 [00:00<00:00, 43151.28 examples/s]
# Casting the dataset: 100% 20/20 [00:00<00:00, 9856.20 examples/s]
# Casting the dataset: 100% 20/20 [00:00<00:00, 9845.78 examples/s]
# Map: 100% 95/95 [00:00<00:00, 13926.29 examples/s]
# Casting the dataset: 100% 95/95 [00:00<00:00, 45074.53 examples/s]
# Map: 100% 20/20 [00:00<00:00, 5012.01 examples/s]
# Casting the dataset: 100% 20/20 [00:00<00:00, 9386.38 examples/s]
# Map: 100% 20/20 [00:00<00:00, 5127.51 examples/s]
# Casting the dataset: 100% 20/20 [00:00<00:00, 9142.90 examples/s]
# Map: 100% 1366/1366 [00:00<00:00, 12091.44 examples/s]
# Map: 100% 1014/1014 [00:00<00:00, 13352.79 examples/s]
# Map: 100% 757/757 [00:00<00:00, 13470.60 examples/s]
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ Waiting for wandb.init()...
# wandb: ⣾ Waiting for wandb.init()...
# wandb: ⣷ setting up run 2lrl3wil (0.4s)
# wandb: Tracking run with wandb version 0.28.1
# wandb: Run data is saved locally in /content/drive/MyDrive/incremental_learning_on_the_edge/src/wandb/run-20260914_202441-2lrl3wil
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run PRODLIVE_v5_a0.2_s42-v5
# wandb: ⭐️ View project at https://wandb.ai/bruno-santome-antolin-city-university-of-london/kd-multilingual-jhu-clsp-ettin-encoder-68m
# wandb: 🚀 View run at https://wandb.ai/bruno-santome-antolin-city-university-of-london/kd-multilingual-jhu-clsp-ettin-encoder-68m/runs/2lrl3wil
# training epoch: 0/20: 100% 43/43 [00:04<00:00,  9.59it/s]
# testing epoch: 0/20: 100% 24/24 [00:00<00:00, 31.97it/s]
# Saving checkpoint
# training epoch: 1/20: 100% 43/43 [00:04<00:00,  9.45it/s]
# testing epoch: 1/20: 100% 24/24 [00:00<00:00, 32.24it/s]
# Saving checkpoint
# training epoch: 2/20: 100% 43/43 [00:04<00:00,  9.59it/s]
# testing epoch: 2/20: 100% 24/24 [00:00<00:00, 32.10it/s]
# training epoch: 3/20: 100% 43/43 [00:04<00:00,  9.21it/s]
# testing epoch: 3/20: 100% 24/24 [00:00<00:00, 32.56it/s]
# training epoch: 4/20: 100% 43/43 [00:04<00:00,  9.25it/s]
# testing epoch: 4/20: 100% 24/24 [00:00<00:00, 32.33it/s]
# Saving checkpoint
# training epoch: 5/20: 100% 43/43 [00:04<00:00,  9.42it/s]
# testing epoch: 5/20: 100% 24/24 [00:00<00:00, 32.06it/s]
# Saving checkpoint
# training epoch: 6/20: 100% 43/43 [00:04<00:00,  9.64it/s]
# testing epoch: 6/20: 100% 24/24 [00:00<00:00, 32.07it/s]
# Saving checkpoint
# training epoch: 7/20: 100% 43/43 [00:04<00:00,  9.39it/s]
# testing epoch: 7/20: 100% 24/24 [00:00<00:00, 32.12it/s]
# training epoch: 8/20: 100% 43/43 [00:04<00:00,  9.50it/s]
# testing epoch: 8/20: 100% 24/24 [00:00<00:00, 31.84it/s]
# Saving checkpoint
# training epoch: 9/20: 100% 43/43 [00:04<00:00,  9.09it/s]
# testing epoch: 9/20: 100% 24/24 [00:00<00:00, 32.61it/s]
# training epoch: 10/20: 100% 43/43 [00:04<00:00,  9.46it/s]
# testing epoch: 10/20: 100% 24/24 [00:00<00:00, 32.27it/s]
# training epoch: 11/20: 100% 43/43 [00:04<00:00,  9.46it/s]
# testing epoch: 11/20: 100% 24/24 [00:00<00:00, 32.49it/s]
# Saving checkpoint
# training epoch: 12/20: 100% 43/43 [00:04<00:00,  9.44it/s]
# testing epoch: 12/20: 100% 24/24 [00:00<00:00, 32.21it/s]
# training epoch: 13/20: 100% 43/43 [00:04<00:00,  9.55it/s]
# testing epoch: 13/20: 100% 24/24 [00:00<00:00, 32.45it/s]
# Saving checkpoint
# training epoch: 14/20: 100% 43/43 [00:04<00:00,  9.15it/s]
# testing epoch: 14/20: 100% 24/24 [00:00<00:00, 32.87it/s]
# training epoch: 15/20: 100% 43/43 [00:04<00:00,  9.43it/s]
# testing epoch: 15/20: 100% 24/24 [00:00<00:00, 32.01it/s]
# training epoch: 16/20: 100% 43/43 [00:04<00:00,  9.32it/s]
# testing epoch: 16/20: 100% 24/24 [00:00<00:00, 31.65it/s]
# training epoch: 17/20: 100% 43/43 [00:04<00:00,  9.24it/s]
# testing epoch: 17/20: 100% 24/24 [00:00<00:00, 31.48it/s]
# training epoch: 18/20: 100% 43/43 [00:04<00:00,  9.24it/s]
# testing epoch: 18/20: 100% 24/24 [00:00<00:00, 30.12it/s]
# Early stopping at epoch 18
# wandb: ⢿ updating run metadata (0.0s)
# wandb: ⣻ updating run metadata (0.0s)
# wandb: ⣽ updating run metadata (0.0s)
# wandb: ⣾ updating run metadata (0.0s)
# wandb: ⣷ uploading output.log 2.3KB/2.3KB (0.1s)
# wandb: ⣷ uploading wandb-summary.json 1.2KB/1.2KB (0.1s)
# wandb: ⣷ uploading config.yaml 2.8KB/2.8KB (0.1s)
# wandb: ⣯ uploading output.log 2.3KB/2.3KB (0.1s)
# wandb: ⣯ uploading wandb-summary.json 1.2KB/1.2KB (0.1s)
# wandb: ⣯ uploading config.yaml 2.8KB/2.8KB (0.1s)
# wandb: ⣟ uploading output.log 2.3KB/2.3KB (0.1s)
# wandb: ⣟ uploading wandb-summary.json 1.2KB/1.2KB (0.1s)
# wandb: ⣟ uploading config.yaml 2.8KB/2.8KB (0.1s)
# wandb: ⡿ uploading output.log 2.3KB/2.3KB (0.1s)
# wandb: ⡿ uploading wandb-summary.json 1.2KB/1.2KB (0.1s)
# wandb: ⡿ uploading config.yaml 2.8KB/2.8KB (0.1s)
# wandb: ⢿ uploading output.log 2.3KB/2.3KB (0.1s)
# wandb: ⢿ uploading wandb-summary.json 1.2KB/1.2KB (0.1s)
# wandb: ⢿ uploading config.yaml 2.8KB/2.8KB (0.1s)
# wandb: ⣻ uploading wandb-summary.json 1.2KB/1.2KB (0.6s)
# wandb: ⣻ uploading config.yaml 2.8KB/2.8KB (0.6s)
# wandb: ⣽ uploading wandb-summary.json 1.2KB/1.2KB (0.6s)
# wandb: ⣽ uploading config.yaml 2.8KB/2.8KB (0.6s)
# wandb: ⣾ uploading wandb-summary.json 1.2KB/1.2KB (0.6s)
# wandb: ⣾ uploading config.yaml 2.8KB/2.8KB (0.6s)
# wandb: ⣷ uploading wandb-summary.json 1.2KB/1.2KB (0.6s)
# wandb: ⣷ uploading config.yaml 2.8KB/2.8KB (0.6s)
# wandb: ⣯ uploading wandb-summary.json 1.2KB/1.2KB (0.6s)
# wandb: ⣯ uploading config.yaml 2.8KB/2.8KB (0.6s)
# wandb: ⣟ uploading history steps 748-835, summary, console lines 42-46 (0.3s)
# wandb: ⡿ uploading history steps 748-835, summary, console lines 42-46 (0.3s)
# wandb:
# wandb: Run history:
# wandb:                      epoch ▁▁▂▂▃▃▃▄▄▅▅▅▆▆▆▇▇██
# wandb:              eval_accuracy ▄▇▁▄▃▄▇▇▇▇▇▇▇█▇▇███
# wandb:        eval_accuracy_en-US ▄▇▁▄▃▄▇▇▇▇▇▇▇█▇▇███
# wandb:          eval_f1_alarm_set ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:  eval_f1_audio_volume_down ▁▁█▁▁▁▁█▁▁▁▁▁█▁▁███
# wandb:  eval_f1_audio_volume_mute █████▁█████████████
# wandb:    eval_f1_audio_volume_up ████▁▅▅▅▃▃▃▃▃▅▃▃▅▅▅
# wandb:  eval_f1_car_brake_control █████▁█████████████
# wandb:   eval_f1_car_door_control ▆█▆█▃▁███▆▆▆▆▆▆▆▆▆▆
# wandb: eval_f1_car_lights_control █▅▅█▅▁▅▅▅▅▅▅▅▅▅▅▅▅▅
# wandb:                        +21 ...
# wandb:
# wandb: Run summary:
# wandb:                      epoch 18
# wandb:              eval_accuracy 0.94848
# wandb:        eval_accuracy_en-US 0.94848
# wandb:          eval_f1_alarm_set 0.96774
# wandb:  eval_f1_audio_volume_down 0.93333
# wandb:  eval_f1_audio_volume_mute 0.9375
# wandb:    eval_f1_audio_volume_up 0.84615
# wandb:  eval_f1_car_brake_control 1
# wandb:   eval_f1_car_door_control 0.97561
# wandb: eval_f1_car_lights_control 0.97561
# wandb:                        +21 ...
# wandb:
# wandb: 🚀 View run PRODLIVE_v5_a0.2_s42-v5 at: https://wandb.ai/bruno-santome-antolin-city-university-of-london/kd-multilingual-jhu-clsp-ettin-encoder-68m/runs/2lrl3wil
# wandb: ⭐️ View project at: https://wandb.ai/bruno-santome-antolin-city-university-of-london/kd-multilingual-jhu-clsp-ettin-encoder-68m
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20260914_202441-2lrl3wil/logs
# Filter: 100% 1014/1014 [00:00<00:00, 117952.80 examples/s]
# Map: 100% 914/914 [00:00<00:00, 13490.64 examples/s]
# evaluating test set: 100% 29/29 [00:00<00:00, 33.28it/s]
# V0: has 15 intents on the test split
# Filter: 100% 1014/1014 [00:00<00:00, 115879.90 examples/s]
# Map: 100% 934/934 [00:00<00:00, 12596.36 examples/s]
# evaluating test set: 100% 30/30 [00:00<00:00, 32.48it/s]
# V1: has 16 intents on the test split
# Filter: 100% 1014/1014 [00:00<00:00, 117499.84 examples/s]
# Map: 100% 954/954 [00:00<00:00, 12880.13 examples/s]
# evaluating test set: 100% 30/30 [00:00<00:00, 32.24it/s]
# V2: has 17 intents on the test split
# Filter: 100% 1014/1014 [00:00<00:00, 115102.14 examples/s]
# Map: 100% 974/974 [00:00<00:00, 12877.36 examples/s]
# evaluating test set: 100% 31/31 [00:00<00:00, 32.26it/s]
# V3: has 18 intents on the test split
# Filter: 100% 1014/1014 [00:00<00:00, 117269.81 examples/s]
# Map: 100% 994/994 [00:00<00:00, 12461.00 examples/s]
# evaluating test set: 100% 32/32 [00:00<00:00, 32.54it/s]
# V4: has 19 intents on the test split
# Filter: 100% 1014/1014 [00:00<00:00, 113226.78 examples/s]
# Map: 100% 1014/1014 [00:00<00:00, 12136.41 examples/s]
# evaluating test set: 100% 32/32 [00:00<00:00, 32.39it/s]
# V5: has 20 intents on the test split
#
# retention (old intents)
#                          V0        V1        V2        V3        V4        V5
# alarm_set          0.975610  0.963855  0.975610  0.987654  0.975610  0.987654
# audio_volume_down  1.000000  0.952381  1.000000  1.000000  1.000000  1.000000
# audio_volume_mute  0.939394  0.939394  0.953846  0.939394  0.953846  0.953846
# audio_volume_up    0.916667  0.720000  0.818182  0.818182  0.833333  0.869565
# datetime_query     0.960452  0.960452  0.960452  0.966667  0.960452  0.960452
# email_addcontact   0.923077  0.923077  0.923077  0.923077  0.923077  0.923077
# lists_createoradd  0.945946  0.921053  0.933333  0.933333  0.935065  0.933333
# news_query         0.964427  0.958333  0.967742  0.971429  0.967213  0.971193
# play_audiobook     0.805195  0.781609  0.805195  0.784810  0.784810  0.794872
# play_game          0.861538  0.835821  0.882353  0.848485  0.882353  0.882353
# play_music         0.928962  0.924419  0.920000  0.919540  0.907514  0.910145
# play_radio         0.936170  0.931507  0.928571  0.930556  0.915493  0.923077
# transport_query    0.907216  0.929293  0.916667  0.916667  0.905263  0.905263
# transport_taxi     1.000000  1.000000  0.977778  0.977778  1.000000  1.000000
# weather_query      0.980769  0.980645  0.980519  0.963455  0.963696  0.963696
# mean_old           0.936362  0.914789  0.929555  0.925402  0.927182  0.931902
#
# acquisition (new intents)
#                       V0        V1        V2        V3        V4        V5
# car_lights_control  None  0.727273  0.760000  0.760000  0.808511  0.844444
# car_door_control    None       NaN  0.666667  0.730769  0.703704  0.760000
# speed_camera_query  None       NaN       NaN  0.800000  0.784314  0.800000
# car_brake_control   None       NaN       NaN       NaN  0.950000  0.950000
# tell_joke           None       NaN       NaN       NaN       NaN  0.754717
# mean_new             NaN  0.727273  0.713333  0.763590  0.811632  0.821832
# server published v5 (tell_joke)
# [edge v5] now predicts 'tell_joke' (confidence 1.00)
#
# utterance (exit/quit to stop)> I want a podcast called my favourite murder
# [edge v5] predicted 'play_radio' (confidence 0.99)
#
# utterance (exit/quit to stop)> I want a podcast
# [edge v5] predicted 'play_radio' (confidence 1.00)
#
# utterance (exit/quit to stop)> Could you tell me the traffic in the next 10 kilometers
# [edge v5] predicted 'speed_camera_query' (confidence 0.97)
#
# utterance (exit/quit to stop)> recommend me a near by food place
# [edge v5] predicted 'speed_camera_query' (confidence 0.39)
# [edge] OOD: escalating
# v6: production intent 'restaurant_recommendation_nearby'
# Casting the dataset: 100% 93/93 [00:00<00:00, 41251.09 examples/s]
# Casting the dataset: 100% 20/20 [00:00<00:00, 9644.30 examples/s]
# Casting the dataset: 100% 20/20 [00:00<00:00, 9818.13 examples/s]
# Map: 100% 93/93 [00:00<00:00, 13943.53 examples/s]
# Casting the dataset: 100% 93/93 [00:00<00:00, 44432.20 examples/s]
# Map: 100% 20/20 [00:00<00:00, 5027.63 examples/s]
# Casting the dataset: 100% 20/20 [00:00<00:00, 9062.89 examples/s]
# Map: 100% 20/20 [00:00<00:00, 5028.84 examples/s]
# Casting the dataset: 100% 20/20 [00:00<00:00, 9340.39 examples/s]
# Map: 100% 1436/1436 [00:00<00:00, 11981.94 examples/s]
# Map: 100% 1034/1034 [00:00<00:00, 13405.14 examples/s]
# Map: 100% 777/777 [00:00<00:00, 14313.40 examples/s]
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ Waiting for wandb.init()...
# wandb: ⣾ Waiting for wandb.init()...
# wandb: ⣷ setting up run x00ra1k2 (0.3s)
# wandb: Tracking run with wandb version 0.28.1
# wandb: Run data is saved locally in /content/drive/MyDrive/incremental_learning_on_the_edge/src/wandb/run-20260914_202905-x00ra1k2
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run PRODLIVE_v6_a0.2_s42-v6
# wandb: ⭐️ View project at https://wandb.ai/bruno-santome-antolin-city-university-of-london/kd-multilingual-jhu-clsp-ettin-encoder-68m
# wandb: 🚀 View run at https://wandb.ai/bruno-santome-antolin-city-university-of-london/kd-multilingual-jhu-clsp-ettin-encoder-68m/runs/x00ra1k2
# training epoch: 0/20: 100% 45/45 [00:04<00:00,  9.56it/s]
# testing epoch: 0/20: 100% 25/25 [00:00<00:00, 32.16it/s]
# Saving checkpoint
# training epoch: 1/20: 100% 45/45 [00:04<00:00,  9.26it/s]
# testing epoch: 1/20: 100% 25/25 [00:00<00:00, 32.12it/s]
# Saving checkpoint
# training epoch: 2/20: 100% 45/45 [00:04<00:00,  9.44it/s]
# testing epoch: 2/20: 100% 25/25 [00:00<00:00, 32.28it/s]
# Saving checkpoint
# training epoch: 3/20: 100% 45/45 [00:04<00:00,  9.32it/s]
# ...
# wandb: ⣽ uploading wandb-summary.json 1.3KB/1.3KB (0.6s)
# wandb: ⣽ uploading config.yaml 2.8KB/2.8KB (0.6s)
# wandb: ⣾ uploading wandb-summary.json 1.3KB/1.3KB (0.6s)
# wandb: ⣾ uploading config.yaml 2.8KB/2.8KB (0.6s)
# wandb: ⣷ uploading wandb-summary.json 1.3KB/1.3KB (0.6s)
# wandb: ⣷ uploading config.yaml 2.8KB/2.8KB (0.6s)
# wandb:
# wandb: Run history:
# wandb:                      epoch ▁▂▃▄▅▆▇█
# wandb:              eval_accuracy ▁█▃▃▆▃▃█
# wandb:        eval_accuracy_en-US ▁█▃▃▆▃▃█
# wandb:          eval_f1_alarm_set ▁▁▁▁▁▁▁▁
# wandb:  eval_f1_audio_volume_down ██▁▁▁▁▁▁
# wandb:  eval_f1_audio_volume_mute ▁▁▁▁▁▁▁▁
# wandb:    eval_f1_audio_volume_up ██▁█▁▁▁▁
# wandb:  eval_f1_car_brake_control ▁▁▁▁▁▁▁▁
# wandb:   eval_f1_car_door_control █▄▁▄▄▄▄█
# wandb: eval_f1_car_lights_control ██▁██▁▁▁
# wandb:                        +22 ...
# wandb:
# wandb: Run summary:
# wandb:                      epoch 7
# wandb:              eval_accuracy 0.9408
# wandb:        eval_accuracy_en-US 0.9408
# wandb:          eval_f1_alarm_set 0.96774
# wandb:  eval_f1_audio_volume_down 0.85714
# wandb:  eval_f1_audio_volume_mute 0.9375
# wandb:    eval_f1_audio_volume_up 0.81481
# wandb:  eval_f1_car_brake_control 1
# wandb:   eval_f1_car_door_control 1
# wandb: eval_f1_car_lights_control 0.97561
# wandb:                        +22 ...
# wandb:
# wandb: 🚀 View run PRODLIVE_v6_a0.2_s42-v6 at: https://wandb.ai/bruno-santome-antolin-city-university-of-london/kd-multilingual-jhu-clsp-ettin-encoder-68m/runs/x00ra1k2
# wandb: ⭐️ View project at: https://wandb.ai/bruno-santome-antolin-city-university-of-london/kd-multilingual-jhu-clsp-ettin-encoder-68m
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20260914_202905-x00ra1k2/logs
# Filter: 100% 1034/1034 [00:00<00:00, 118835.74 examples/s]
# Map: 100% 914/914 [00:00<00:00, 14060.24 examples/s]
# evaluating test set: 100% 29/29 [00:00<00:00, 33.41it/s]
# V0: has 15 intents on the test split
# Filter: 100% 1034/1034 [00:00<00:00, 122225.02 examples/s]
# Map: 100% 934/934 [00:00<00:00, 13852.67 examples/s]
# evaluating test set: 100% 30/30 [00:00<00:00, 33.31it/s]
# V1: has 16 intents on the test split
# Filter: 100% 1034/1034 [00:00<00:00, 118579.05 examples/s]
# Map: 100% 954/954 [00:00<00:00, 12178.46 examples/s]
# evaluating test set: 100% 30/30 [00:00<00:00, 32.23it/s]
# V2: has 17 intents on the test split
# Filter: 100% 1034/1034 [00:00<00:00, 120560.15 examples/s]
# Map: 100% 974/974 [00:00<00:00, 13156.55 examples/s]
# evaluating test set: 100% 31/31 [00:00<00:00, 32.23it/s]
# V3: has 18 intents on the test split
# Filter: 100% 1034/1034 [00:00<00:00, 117866.84 examples/s]
# Map: 100% 994/994 [00:00<00:00, 12070.29 examples/s]
# evaluating test set: 100% 32/32 [00:00<00:00, 32.53it/s]
# V4: has 19 intents on the test split
# Filter: 100% 1034/1034 [00:00<00:00, 111523.10 examples/s]
# Map: 100% 1014/1014 [00:00<00:00, 12258.32 examples/s]
# evaluating test set: 100% 32/32 [00:00<00:00, 32.35it/s]
# V5: has 20 intents on the test split
# Filter: 100% 1034/1034 [00:00<00:00, 110986.55 examples/s]
# Map: 100% 1034/1034 [00:00<00:00, 11595.64 examples/s]
# evaluating test set: 100% 33/33 [00:01<00:00, 31.85it/s]
# V6: has 21 intents on the test split
#
# retention (old intents)
#                          V0        V1        V2  ...        V4        V5        V6
# alarm_set          0.975610  0.963855  0.975610  ...  0.975610  0.987654  0.987654
# audio_volume_down  1.000000  0.952381  1.000000  ...  1.000000  1.000000  1.000000
# audio_volume_mute  0.939394  0.939394  0.953846  ...  0.953846  0.953846  0.953846
# audio_volume_up    0.916667  0.720000  0.818182  ...  0.833333  0.869565  0.880000
# datetime_query     0.960452  0.960452  0.960452  ...  0.960452  0.960452  0.955056
# email_addcontact   0.923077  0.923077  0.923077  ...  0.923077  0.923077  0.923077
# lists_createoradd  0.945946  0.921053  0.933333  ...  0.935065  0.933333  0.906667
# news_query         0.964427  0.958333  0.967742  ...  0.967213  0.971193  0.962656
# play_audiobook     0.805195  0.781609  0.805195  ...  0.784810  0.794872  0.765432
# play_game          0.861538  0.835821  0.882353  ...  0.882353  0.882353  0.895522
# play_music         0.928962  0.924419  0.920000  ...  0.907514  0.910145  0.890208
# play_radio         0.936170  0.931507  0.928571  ...  0.915493  0.923077  0.929577
# transport_query    0.907216  0.929293  0.916667  ...  0.905263  0.905263  0.903226
# transport_taxi     1.000000  1.000000  0.977778  ...  1.000000  1.000000  0.977778
# weather_query      0.980769  0.980645  0.980519  ...  0.963696  0.963696  0.960265
# mean_old           0.936362  0.914789  0.929555  ...  0.927182  0.931902  0.926064
#
# [16 rows x 7 columns]
#
# acquisition (new intents)
#                                     V0        V1  ...        V5        V6
# car_lights_control                None  0.727273  ...  0.844444  0.863636
# car_door_control                  None       NaN  ...  0.760000  0.826087
# speed_camera_query                None       NaN  ...  0.800000  0.869565
# car_brake_control                 None       NaN  ...  0.950000  0.926829
# tell_joke                         None       NaN  ...  0.754717  0.754717
# restaurant_recommendation_nearby  None       NaN  ...       NaN  0.689655
# mean_new                           NaN  0.727273  ...  0.821832  0.821748
#
# [7 rows x 7 columns]
# server published v6 (restaurant_recommendation_nearby)
# [edge v6] now predicts 'restaurant_recommendation_nearby' (confidence 1.00)
#
# utterance (exit/quit to stop)> I need urgently a petrol station
# [edge v6] predicted 'restaurant_recommendation_nearby' (confidence 0.85)
# [edge] OOD: escalating
# v7: production intent 'gas_station_nearby'
# Casting the dataset: 100% 95/95 [00:00<00:00, 44067.56 examples/s]
# Casting the dataset: 100% 20/20 [00:00<00:00, 9716.91 examples/s]
# Casting the dataset: 100% 20/20 [00:00<00:00, 9884.07 examples/s]
# Map: 100% 95/95 [00:00<00:00, 14132.25 examples/s]
# Casting the dataset: 100% 95/95 [00:00<00:00, 44800.86 examples/s]
# Map: 100% 20/20 [00:00<00:00, 5049.12 examples/s]
# Casting the dataset: 100% 20/20 [00:00<00:00, 9569.48 examples/s]
# Map: 100% 20/20 [00:00<00:00, 5066.50 examples/s]
# Casting the dataset: 100% 20/20 [00:00<00:00, 9266.11 examples/s]
# Map: 100% 1506/1506 [00:00<00:00, 11599.65 examples/s]
# Map: 100% 1054/1054 [00:00<00:00, 14257.51 examples/s]
# Map: 100% 797/797 [00:00<00:00, 14149.55 examples/s]
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ Waiting for wandb.init()...
# wandb: ⣾ Waiting for wandb.init()...
# wandb: ⣷ setting up run ni4o9d7m (0.4s)
# wandb: Tracking run with wandb version 0.28.1
# wandb: Run data is saved locally in /content/drive/MyDrive/incremental_learning_on_the_edge/src/wandb/run-20260914_203053-ni4o9d7m
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run PRODLIVE_v7_a0.2_s42-v7
# wandb: ⭐️ View project at https://wandb.ai/bruno-santome-antolin-city-university-of-london/kd-multilingual-jhu-clsp-ettin-encoder-68m
# wandb: 🚀 View run at https://wandb.ai/bruno-santome-antolin-city-university-of-london/kd-multilingual-jhu-clsp-ettin-encoder-68m/runs/ni4o9d7m
# training epoch: 0/20: 100% 48/48 [00:05<00:00,  9.30it/s]
# testing epoch: 0/20: 100% 25/25 [00:00<00:00, 32.04it/s]
# Saving checkpoint
# training epoch: 1/20: 100% 48/48 [00:05<00:00,  9.53it/s]
# testing epoch: 1/20: 100% 25/25 [00:00<00:00, 33.59it/s]
# Saving checkpoint
# training epoch: 2/20: 100% 48/48 [00:05<00:00,  8.78it/s]
# testing epoch: 2/20: 100% 25/25 [00:00<00:00, 32.24it/s]
# training epoch: 3/20: 100% 48/48 [00:05<00:00,  9.47it/s]
# testing epoch: 3/20: 100% 25/25 [00:00<00:00, 32.98it/s]
# training epoch: 4/20: 100% 48/48 [00:05<00:00,  9.13it/s]
# testing epoch: 4/20: 100% 25/25 [00:00<00:00, 31.28it/s]
# training epoch: 5/20: 100% 48/48 [00:05<00:00,  9.42it/s]
# testing epoch: 5/20: 100% 25/25 [00:00<00:00, 33.27it/s]
# Saving checkpoint
# training epoch: 6/20: 100% 48/48 [00:05<00:00,  9.27it/s]
# testing epoch: 6/20: 100% 25/25 [00:00<00:00, 30.97it/s]
# Saving checkpoint
# training epoch: 7/20: 100% 48/48 [00:05<00:00,  9.48it/s]
# testing epoch: 7/20: 100% 25/25 [00:00<00:00, 32.76it/s]
# training epoch: 8/20: 100% 48/48 [00:05<00:00,  8.73it/s]
# testing epoch: 8/20: 100% 25/25 [00:00<00:00, 31.37it/s]
# Saving checkpoint
# training epoch: 9/20: 100% 48/48 [00:05<00:00,  9.49it/s]
# testing epoch: 9/20: 100% 25/25 [00:00<00:00, 32.32it/s]
# Saving checkpoint
# training epoch: 10/20: 100% 48/48 [00:05<00:00,  9.35it/s]
# testing epoch: 10/20: 100% 25/25 [00:00<00:00, 32.03it/s]
# Saving checkpoint
# training epoch: 11/20: 100% 48/48 [00:05<00:00,  8.55it/s]
# testing epoch: 11/20: 100% 25/25 [00:00<00:00, 31.81it/s]
# training epoch: 12/20: 100% 48/48 [00:05<00:00,  9.42it/s]
# testing epoch: 12/20: 100% 25/25 [00:00<00:00, 33.05it/s]
# Saving checkpoint
# training epoch: 13/20: 100% 48/48 [00:05<00:00,  8.67it/s]
# testing epoch: 13/20: 100% 25/25 [00:00<00:00, 29.91it/s]
# training epoch: 14/20: 100% 48/48 [00:05<00:00,  9.46it/s]
# testing epoch: 14/20: 100% 25/25 [00:00<00:00, 31.98it/s]
# training epoch: 15/20: 100% 48/48 [00:05<00:00,  9.32it/s]
# testing epoch: 15/20: 100% 25/25 [00:00<00:00, 31.71it/s]
# training epoch: 16/20: 100% 48/48 [00:05<00:00,  9.04it/s]
# testing epoch: 16/20: 100% 25/25 [00:00<00:00, 32.20it/s]
# training epoch: 17/20: 100% 48/48 [00:05<00:00,  9.48it/s]
# testing epoch: 17/20: 100% 25/25 [00:00<00:00, 32.98it/s]
# Saving checkpoint
# training epoch: 18/20: 100% 48/48 [00:05<00:00,  9.46it/s]
# testing epoch: 18/20: 100% 25/25 [00:00<00:00, 32.02it/s]
# training epoch: 19/20: 100% 48/48 [00:05<00:00,  9.45it/s]
# testing epoch: 19/20: 100% 25/25 [00:00<00:00, 31.81it/s]
# wandb: ⢿ updating run metadata (0.0s)
# wandb: ⣻ updating run metadata (0.0s)
# wandb: ⣽ updating run metadata (0.0s)
# wandb: ⣾ updating run metadata (0.0s)
# wandb: ⣷ Finishing up...
# wandb: ⣯ Finishing up...
# wandb: ⣟ Finishing up...
# wandb: ⡿ Finishing up...
# wandb: ⢿ Finishing up...
# wandb: ⣻ uploading config.yaml 2.8KB/2.8KB (0.5s)
# wandb: ⣻ uploading output.log 2.4KB/2.4KB (0.5s)
# wandb: ⣽ uploading config.yaml 2.8KB/2.8KB (0.5s)
# wandb: ⣽ uploading output.log 2.4KB/2.4KB (0.5s)
# wandb: ⣾ uploading config.yaml 2.8KB/2.8KB (0.5s)
# wandb: ⣾ uploading output.log 2.4KB/2.4KB (0.5s)
# wandb: ⣷ uploading config.yaml 2.8KB/2.8KB (0.5s)
# wandb: ⣷ uploading output.log 2.4KB/2.4KB (0.5s)
# wandb: ⣯ uploading config.yaml 2.8KB/2.8KB (0.5s)
# wandb: ⣯ uploading output.log 2.4KB/2.4KB (0.5s)
# wandb: ⣟ uploading history steps 902-979, summary, console lines 45-48 (0.3s)
# wandb: ⡿ uploading history steps 902-979, summary, console lines 45-48 (0.3s)
# wandb:
# wandb: Run history:
# wandb:                      epoch ▁▁▂▂▂▃▃▄▄▄▅▅▅▆▆▇▇▇██
# wandb:              eval_accuracy ▁█▆▆▇█▇▇████████████
# wandb:        eval_accuracy_en-US ▁█▆▆▇█▇▇████████████
# wandb:          eval_f1_alarm_set ▁███████████████████
# wandb:  eval_f1_audio_volume_down ▁▁▁▁▁█▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:  eval_f1_audio_volume_mute ▁█▁█▁███████████████
# wandb:    eval_f1_audio_volume_up █▄█▁▁▄▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:  eval_f1_car_brake_control ███▁████████████████
# wandb:   eval_f1_car_door_control █▄▄██▄▄▁▄▄▄▄▄▄▄▄▄▄▄▄
# wandb: eval_f1_car_lights_control ███▁██▁█▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:                        +23 ...
# wandb:
# wandb: Run summary:
# wandb:                      epoch 19
# wandb:              eval_accuracy 0.93977
# wandb:        eval_accuracy_en-US 0.93977
# wandb:          eval_f1_alarm_set 0.96774
# wandb:  eval_f1_audio_volume_down 0.85714
# wandb:  eval_f1_audio_volume_mute 0.9375
# wandb:    eval_f1_audio_volume_up 0.81481
# wandb:  eval_f1_car_brake_control 1
# wandb:   eval_f1_car_door_control 0.97561
# wandb: eval_f1_car_lights_control 0.97561
# wandb:                        +23 ...
# wandb:
# wandb: 🚀 View run PRODLIVE_v7_a0.2_s42-v7 at: https://wandb.ai/bruno-santome-antolin-city-university-of-london/kd-multilingual-jhu-clsp-ettin-encoder-68m/runs/ni4o9d7m
# wandb: ⭐️ View project at: https://wandb.ai/bruno-santome-antolin-city-university-of-london/kd-multilingual-jhu-clsp-ettin-encoder-68m
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20260914_203053-ni4o9d7m/logs
# Filter: 100% 1054/1054 [00:00<00:00, 115821.65 examples/s]
# Map: 100% 914/914 [00:00<00:00, 12854.75 examples/s]
# evaluating test set: 100% 29/29 [00:00<00:00, 31.56it/s]
# V0: has 15 intents on the test split
# Filter: 100% 1054/1054 [00:00<00:00, 119642.66 examples/s]
# Map: 100% 934/934 [00:00<00:00, 12564.64 examples/s]
# evaluating test set: 100% 30/30 [00:00<00:00, 30.86it/s]
# V1: has 16 intents on the test split
# Filter: 100% 1054/1054 [00:00<00:00, 120415.01 examples/s]
# Map: 100% 954/954 [00:00<00:00, 12888.63 examples/s]
# evaluating test set: 100% 30/30 [00:00<00:00, 32.74it/s]
# V2: has 17 intents on the test split
# Filter: 100% 1054/1054 [00:00<00:00, 126786.64 examples/s]
# Map: 100% 974/974 [00:00<00:00, 13496.76 examples/s]
# evaluating test set: 100% 31/31 [00:00<00:00, 33.30it/s]
# V3: has 18 intents on the test split
# Filter: 100% 1054/1054 [00:00<00:00, 127691.18 examples/s]
# Map: 100% 994/994 [00:00<00:00, 13686.13 examples/s]
# evaluating test set: 100% 32/32 [00:00<00:00, 32.15it/s]
# V4: has 19 intents on the test split
# Filter: 100% 1054/1054 [00:00<00:00, 118845.00 examples/s]
# Map: 100% 1014/1014 [00:00<00:00, 11670.31 examples/s]
# evaluating test set: 100% 32/32 [00:00<00:00, 32.46it/s]
# V5: has 20 intents on the test split
# Filter: 100% 1054/1054 [00:00<00:00, 117759.15 examples/s]
# Map: 100% 1034/1034 [00:00<00:00, 12176.21 examples/s]
# evaluating test set: 100% 33/33 [00:01<00:00, 32.43it/s]
# V6: has 21 intents on the test split
# Filter: 100% 1054/1054 [00:00<00:00, 111543.32 examples/s]
# Map: 100% 1054/1054 [00:00<00:00, 11782.41 examples/s]
# evaluating test set: 100% 33/33 [00:01<00:00, 32.13it/s]
# V7: has 22 intents on the test split
#
# retention (old intents)
#                          V0        V1        V2  ...        V5        V6        V7
# alarm_set          0.975610  0.963855  0.975610  ...  0.987654  0.987654  0.987654
# audio_volume_down  1.000000  0.952381  1.000000  ...  1.000000  1.000000  1.000000
# audio_volume_mute  0.939394  0.939394  0.953846  ...  0.953846  0.953846  0.953846
# audio_volume_up    0.916667  0.720000  0.818182  ...  0.869565  0.880000  0.880000
# datetime_query     0.960452  0.960452  0.960452  ...  0.960452  0.955056  0.960452
# email_addcontact   0.923077  0.923077  0.923077  ...  0.923077  0.923077  0.923077
# lists_createoradd  0.945946  0.921053  0.933333  ...  0.933333  0.906667  0.906667
# news_query         0.964427  0.958333  0.967742  ...  0.971193  0.962656  0.962656
# play_audiobook     0.805195  0.781609  0.805195  ...  0.794872  0.765432  0.775000
# play_game          0.861538  0.835821  0.882353  ...  0.882353  0.895522  0.895522
# play_music         0.928962  0.924419  0.920000  ...  0.910145  0.890208  0.895522
# play_radio         0.936170  0.931507  0.928571  ...  0.923077  0.929577  0.944444
# transport_query    0.907216  0.929293  0.916667  ...  0.905263  0.903226  0.905263
# transport_taxi     1.000000  1.000000  0.977778  ...  1.000000  0.977778  0.977778
# weather_query      0.980769  0.980645  0.980519  ...  0.963696  0.960265  0.960265
# mean_old           0.936362  0.914789  0.929555  ...  0.931902  0.926064  0.928543
#
# [16 rows x 8 columns]
#
# acquisition (new intents)
#                                     V0        V1  ...        V6        V7
# car_lights_control                None  0.727273  ...  0.863636  0.844444
# car_door_control                  None       NaN  ...  0.826087  0.826087
# speed_camera_query                None       NaN  ...  0.869565  0.869565
# car_brake_control                 None       NaN  ...  0.926829  0.950000
# tell_joke                         None       NaN  ...  0.754717  0.800000
# restaurant_recommendation_nearby  None       NaN  ...  0.689655  0.689655
# gas_station_nearby                None       NaN  ...       NaN  0.883721
# mean_new                           NaN  0.727273  ...  0.821748  0.837639
#
# [8 rows x 8 columns]
# server published v7 (gas_station_nearby)
# [edge v7] now predicts 'gas_station_nearby' (confidence 1.00)
#
# utterance (exit/quit to stop)> exit
