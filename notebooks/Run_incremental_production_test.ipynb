# %% [markdown]
# ### Notebook to train the Teacher and students models

# %%
import os
from google.colab import drive, userdata
drive.mount('/content/drive')
token = userdata.get('githubAccess')
os.environ['WANDB_API_KEY'] = userdata.get('wandbKey')
os.environ["ANTHROPIC_API_KEY"] = userdata.get('anthropic_key')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %pip install -q "transformers>=4.48,<5" "huggingface_hub>=0.34,<1" "datasets<3.0.0" anthropic
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 3.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 131.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 49.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 527.3/527.3 kB 44.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 64.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 13.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.6/177.6 kB 17.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 115.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.7/146.7 kB 16.9 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gradio 6.26.0 requires huggingface-hub<2.0,>=1.16.0, but you have huggingface-hub 0.36.2 which is incompatible.
# diffusers 0.40.0 requires huggingface-hub<2.0,>=1.23.0, but you have huggingface-hub 0.36.2 which is incompatible.
# gcsfs 2025.12.0 requires fsspec==2025.12.0, but you have fsspec 2024.6.1 which is incompatible.

# %%
import sys
print(sys.version)
# Out:
# 3.13.15 (main, Aug  6 2026, 11:06:22) [GCC 13.3.0]

# %%
# %cd /content/drive/MyDrive/incremental_learning_on_the_edge/src
# Out:
# /content/drive/MyDrive/incremental_learning_on_the_edge/src

# %%
# !git pull
# Out:
# Already up to date.

# %%
# !python run_simulation.py
# Out:
# could you open the window of the front of the car
# 2026-09-13 19:10:59.142204: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-09-13 19:10:59.214969: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# tokenizer_config.json: 20.8kB [00:00, 62.5MB/s]
# tokenizer.json: 2.13MB [00:00, 87.2MB/s]
# special_tokens_map.json: 100% 694/694 [00:00<00:00, 5.83MB/s]
# [edge v0] predicted: 'weather_query' with (confidence 0.88)
# edge device OOD: escalating
# Downloading builder script: 100% 32.3k/32.3k [00:00<00:00, 130kB/s]
# Downloading readme: 100% 34.1k/34.1k [00:00<00:00, 156kB/s]
# Downloading data: 100% 39.5M/39.5M [00:01<00:00, 23.6MB/s]
# Generating train split: 11514 examples [00:01, 5920.13 examples/s]
# Generating validation split: 2033 examples [00:00, 2691.92 examples/s]
# Generating test split: 2974 examples [00:00, 3395.23 examples/s]
# Filter: 100% 11514/11514 [00:00<00:00, 204593.26 examples/s]
# Filter: 100% 2974/2974 [00:00<00:00, 184871.88 examples/s]
# Filter: 100% 2033/2033 [00:00<00:00, 166641.00 examples/s]
# Filter: 100% 11514/11514 [00:00<00:00, 223847.08 examples/s]
# Filter: 100% 2974/2974 [00:00<00:00, 181414.22 examples/s]
# Filter: 100% 2033/2033 [00:00<00:00, 165499.29 examples/s]
# Map: 100% 3622/3622 [00:00<00:00, 11895.25 examples/s]
# Map: 100% 914/914 [00:00<00:00, 12104.70 examples/s]
# Map: 100% 657/657 [00:00<00:00, 11631.32 examples/s]
# Casting the dataset: 100% 3622/3622 [00:00<00:00, 800915.70 examples/s]
# Casting the dataset: 100% 914/914 [00:00<00:00, 279375.74 examples/s]
# Casting the dataset: 100% 657/657 [00:00<00:00, 200732.64 examples/s]
# Casting the dataset: 100% 690/690 [00:00<00:00, 69448.78 examples/s]
# Casting the dataset: 100% 150/150 [00:00<00:00, 34068.64 examples/s]
# Casting the dataset: 100% 122/122 [00:00<00:00, 29170.28 examples/s]
# Map: 100% 690/690 [00:00<00:00, 21079.05 examples/s]
# Map: 100% 150/150 [00:00<00:00, 15472.95 examples/s]
# Map: 100% 122/122 [00:00<00:00, 14301.43 examples/s]
# Casting the dataset: 100% 690/690 [00:00<00:00, 250395.38 examples/s]
# Casting the dataset: 100% 150/150 [00:00<00:00, 57247.10 examples/s]
# Casting the dataset: 100% 122/122 [00:00<00:00, 46910.99 examples/s]
# v1: production intent 'car_window_control'
# Casting the dataset: 100% 93/93 [00:00<00:00, 42813.11 examples/s]
# Casting the dataset: 100% 20/20 [00:00<00:00, 10707.95 examples/s]
# Casting the dataset: 100% 20/20 [00:00<00:00, 10749.11 examples/s]
# Map: 100% 93/93 [00:00<00:00, 15835.92 examples/s]
# Casting the dataset: 100% 93/93 [00:00<00:00, 47401.90 examples/s]
# Map: 100% 20/20 [00:00<00:00, 6298.70 examples/s]
# Casting the dataset: 100% 20/20 [00:00<00:00, 10304.15 examples/s]
# Map: 100% 20/20 [00:00<00:00, 6492.23 examples/s]
# Casting the dataset: 100% 20/20 [00:00<00:00, 10712.05 examples/s]
# Map: 100% 1086/1086 [00:00<00:00, 13011.35 examples/s]
# Map: 100% 934/934 [00:00<00:00, 15929.83 examples/s]
# Map: 100% 677/677 [00:00<00:00, 15242.68 examples/s]
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from WANDB_API_KEY.
# wandb: Currently logged in as: bruno-santome-antolin (bruno-santome-antolin-city-university-of-london) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ Waiting for wandb.init()...
# wandb: ⣾ Waiting for wandb.init()...
# wandb: ⣷ setting up run u2fs3yza (0.4s)
# wandb: Tracking run with wandb version 0.28.1
# wandb: Run data is saved locally in /content/drive/MyDrive/incremental_learning_on_the_edge/src/wandb/run-20260913_191158-u2fs3yza
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run PRODLIVE_v1_a0.2_s42-v1
# wandb: ⭐️ View project at https://wandb.ai/bruno-santome-antolin-city-university-of-london/kd-multilingual-jhu-clsp-ettin-encoder-68m
# wandb: 🚀 View run at https://wandb.ai/bruno-santome-antolin-city-university-of-london/kd-multilingual-jhu-clsp-ettin-encoder-68m/runs/u2fs3yza
# wandb: Detected [anthropic] in use.
# wandb: Use W&B Weave for improved LLM call tracing. Install Weave with `pip install weave` then add `import weave` to the top of your script.
# wandb: For more information, check out the docs at: https://weave-docs.wandb.ai
# training epoch: 0/20:   0% 0/34 [00:00<?, ?it/s]/content/drive/MyDrive/incremental_learning_on_the_edge/src/core/distillation_1.py:470: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   self.scheduler.step()
# training epoch: 0/20: 100% 34/34 [00:15<00:00,  2.13it/s]
# testing epoch: 0/20: 100% 22/22 [00:01<00:00, 14.77it/s]
# Saving checkpoint
# training epoch: 1/20: 100% 34/34 [00:03<00:00,  9.66it/s]
# testing epoch: 1/20: 100% 22/22 [00:00<00:00, 33.49it/s]
# training epoch: 2/20: 100% 34/34 [00:03<00:00,  9.61it/s]
# testing epoch: 2/20: 100% 22/22 [00:00<00:00, 32.95it/s]
# training epoch: 3/20: 100% 34/34 [00:03<00:00,  9.57it/s]
# testing epoch: 3/20: 100% 22/22 [00:00<00:00, 33.11it/s]
# training epoch: 4/20: 100% 34/34 [00:03<00:00,  9.87it/s]
# testing epoch: 4/20: 100% 22/22 [00:00<00:00, 33.55it/s]
# training epoch: 5/20: 100% 34/34 [00:03<00:00,  9.94it/s]
# testing epoch: 5/20: 100% 22/22 [00:00<00:00, 33.49it/s]
# Saving checkpoint
# training epoch: 6/20: 100% 34/34 [00:03<00:00,  9.87it/s]
# testing epoch: 6/20: 100% 22/22 [00:00<00:00, 33.23it/s]
# Saving checkpoint
# training epoch: 7/20: 100% 34/34 [00:03<00:00,  9.74it/s]
# testing epoch: 7/20: 100% 22/22 [00:00<00:00, 33.45it/s]
# training epoch: 8/20: 100% 34/34 [00:03<00:00,  9.77it/s]
# testing epoch: 8/20: 100% 22/22 [00:00<00:00, 31.51it/s]
# Saving checkpoint
# training epoch: 9/20: 100% 34/34 [00:03<00:00,  9.21it/s]
# testing epoch: 9/20: 100% 22/22 [00:00<00:00, 31.75it/s]
# training epoch: 10/20: 100% 34/34 [00:03<00:00,  9.80it/s]
# testing epoch: 10/20: 100% 22/22 [00:00<00:00, 33.53it/s]
# training epoch: 11/20: 100% 34/34 [00:03<00:00,  9.81it/s]
# testing epoch: 11/20: 100% 22/22 [00:00<00:00, 33.60it/s]
# training epoch: 12/20: 100% 34/34 [00:03<00:00,  9.72it/s]
# testing epoch: 12/20: 100% 22/22 [00:00<00:00, 32.86it/s]
# training epoch: 13/20: 100% 34/34 [00:03<00:00,  9.57it/s]
# testing epoch: 13/20: 100% 22/22 [00:00<00:00, 33.37it/s]
# Early stopping at epoch 13
# wandb: ⢿ updating run metadata (0.0s)
# wandb: ⣻ updating run metadata (0.0s)
# wandb: ⣽ updating run metadata (0.0s)
# wandb: ⣾ updating run metadata (0.0s)
# wandb: ⣷ Finishing up...
# wandb: ⣯ Finishing up...
# wandb: ⣟ Finishing up...
# wandb: ⡿ Finishing up...
# wandb: ⢿ Finishing up...
# wandb: ⣻ uploading wandb-summary.json 1.1KB/1.1KB (0.5s)
# wandb: ⣻ uploading config.yaml 2.8KB/2.8KB (0.5s)
# wandb: ⣽ uploading wandb-summary.json 1.1KB/1.1KB (0.5s)
# wandb: ⣽ uploading config.yaml 2.8KB/2.8KB (0.5s)
# wandb: ⣾ uploading wandb-summary.json 1.1KB/1.1KB (0.5s)
# wandb: ⣾ uploading config.yaml 2.8KB/2.8KB (0.5s)
# wandb: ⣷ uploading wandb-summary.json 1.1KB/1.1KB (0.5s)
# wandb: ⣷ uploading config.yaml 2.8KB/2.8KB (0.5s)
# wandb: ⣯ uploading wandb-summary.json 1.1KB/1.1KB (0.5s)
# wandb: ⣯ uploading config.yaml 2.8KB/2.8KB (0.5s)
# wandb:
# wandb: Run history:
# wandb:                      epoch ▁▂▂▃▃▄▄▅▅▆▆▇▇█
# wandb:              eval_accuracy ▇▄▄▄▁▂▄▅▆▇█▇▇▇
# wandb:        eval_accuracy_en-US ▇▄▄▄▁▂▄▅▆▇█▇▇▇
# wandb:          eval_f1_alarm_set ▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:  eval_f1_audio_volume_down ███▁██████████
# wandb:  eval_f1_audio_volume_mute █▁▁▁▁▁▁▁██████
# wandb:    eval_f1_audio_volume_up ▁█▁▁▁▁▁▁▁▁▁▁▁▁
# wandb: eval_f1_car_window_control ▅▃▃▃▁▆▆▅█▇▇▇▇▇
# wandb:     eval_f1_datetime_query ▁▁█▁█▁▁▁▁▁▁▁▁▁
# wandb:   eval_f1_email_addcontact ▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:                        +17 ...
# wandb:
# wandb: Run summary:
# wandb:                      epoch 13
# wandb:              eval_accuracy 0.9616
# wandb:        eval_accuracy_en-US 0.9616
# wandb:          eval_f1_alarm_set 0.96774
# wandb:  eval_f1_audio_volume_down 0.93333
# wandb:  eval_f1_audio_volume_mute 0.9375
# wandb:    eval_f1_audio_volume_up 0.88
# wandb: eval_f1_car_window_control 0.97561
# wandb:     eval_f1_datetime_query 0.97638
# wandb:   eval_f1_email_addcontact 1
# wandb:                        +17 ...
# wandb:
# wandb: 🚀 View run PRODLIVE_v1_a0.2_s42-v1 at: https://wandb.ai/bruno-santome-antolin-city-university-of-london/kd-multilingual-jhu-clsp-ettin-encoder-68m/runs/u2fs3yza
# wandb: ⭐️ View project at: https://wandb.ai/bruno-santome-antolin-city-university-of-london/kd-multilingual-jhu-clsp-ettin-encoder-68m
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20260913_191158-u2fs3yza/logs
# server published v1 (car_window_control)
# could you close the rear-window please
# [edge v1] predicted 'car_window_control' (confidence 1.00)
